# %%
import pandas as pd

# %%
df = pd.read_csv('test_ansi.csv', sep=';', encoding='mbcs')
df
# Out:
#     Местное время в Норильске       T     Po      P    Pa     U  \
# 0            25.09.2023 10:00  04.фев  746.8  752.7  -0.6  82.0
# 1             25.09.2023 7:00     4.0  747.4  753.4  -2.4  82.0
# 2             25.09.2023 4:00  03.янв  749.8  755.8  -1.8  72.0
# 3             25.09.2023 1:00  02.сен  751.6  757.6  -1.0  73.0
# 4            24.09.2023 22:00  02.апр  752.6  758.7  -0.6  74.0
# ..                        ...     ...    ...    ...   ...   ...
# 191          01.09.2023 13:00  07.авг  762.4  768.4  -0.2  90.0
# 192          01.09.2023 10:00  04.июл  762.6  768.7   0.0  97.0
# 193           01.09.2023 7:00  02.янв  762.6  768.7   0.5  98.0
# 194           01.09.2023 4:00  02.июл  762.1  768.3   0.0  94.0
# 195           01.09.2023 1:00  04.июн  762.1  768.1   0.6  85.0
#
#                                        DD  Ff  ff10   ff3  ...  \
# 0                  Ветер, дующий с запада  18  25.0  25.0  ...
# 1       Ветер, дующий с западо-юго-запада  17  25.0  25.0  ...
# ...
