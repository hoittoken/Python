# %% [markdown]
# # Данные из веб-источников и API
#
# ###  Содержание <a class="anchor" id=0></a>
# - [1. Intro](#1)
# - [2. Веб-запросы](#2)
# - [3. Библиотека requests](#3)
# - [4. Парсинг сайтов](#4)
# - [4.1 Получаем содержание веб-страниц](#4-1)
# - [5. Библиотека BeautifulShop](#5)
# - [5.1 Сбор ](#5-1)
# - [6. Работа с API](#6)
# - [6.1 Первые запросы в API](#6-1)
# - [6.2 Запросы к API из кода](#6-2)
# - [6.3 Сбор информации из групп](#6-3)
# - [6.4 Ограничение по частоте запросов](#6-4)
# - [6.5 Другие API (Google Map, YouTube, Twitter, etc)](#6-5)
# - [7. Регулярная выгрузка данных](#7)
# - [8. Итоги](#8)
# - [9. Подготовка к аттестации по Python](#9)
#
# В этом модуле мы рассмотрим, как с помощью Python можно упростить сбор информации из интернета и, в некоторых случаях, получить доступ к данным, которые невозможно «собрать руками». В частности, мы:
#
# * рассмотрим, в каком виде информация обычно находится в интернете;
# * напишем программы, которые собирают данные с веб-сайтов, используя библиотеки `requests` и `BeautifulSoup`;
# * разберёмся, что такое программный интерфейс веб-сервисов (`API`) и как его использовать (для примера мы будем собирать данные в социальной сети ВКонтакте).
#
# К концу изучения модуля вы сможете писать программы, которые избавят вас от многих часов монотонной работы и расширят спектр собираемой информации.

# %% [markdown]
# ## 2. Веб-запросы <a class="anchor" id=2></a>
#
# [к содержанию](#0)
#
# Процесс получения/извлечения информации с веб-ресурсов в интернете называется **web-scraping** (рус. веб-скрейпинг/веб-скрапинг). Веб-скрапинг может быть проделан вручную пользователем компьютера, однако этот термин обычно связывают с автоматизированными процессами, реализованными с помощью кода.
#
# Какие данные можно извлечь в процессе веб-скрапинга?
#
# - цены на товары конкурентов для оптимизации своей стратегии ценообразования;
# - сообщения в социальных медиа, по которым можно отслеживать тренды в той или иной области;
# - отзывы о товарах/услугах компании на различных площадках, которые можно впоследствии анализировать;
# - контактные данные пользователей соцсетей или форумов для дальнейшего взаимодействия с этими пользователями;
# - и т.д.
#
# <img src=p_17_img1.png width="450">
#
# >Клиент и сервер взаимодействуют между собой, обмениваясь одиночными сообщениями (не потоком данных) посредством сетевых протоколов, которые формализуют общение между ними. В настоящее время повсеместно используемый протокол в интернете, позволяющий клиенту получать различные ресурсы (например, HTML-документы), — это протокол HTTP.
#
# **Запрос**, отправляемый клиентом с использованием протокола HTTP, состоит из нескольких элементов:
#
# * адрес, по которому идёт обращение (например, www.google.com);
# * техническая информация, например метод запроса;
# * дополнительные данные, например если загружается (передаётся) изображение.
#
# **Ответ**, в свою очередь, состоит из следующих элементов:
#
# * код статуса ответа: например, 200 («успешно»), 404 («не найден») и т. д. (более полный список кодов статуса ответа можете посмотреть, перейдя по ссылке);
# * текст в запрошенном формате (HTML, XML, JSON и т. д.) или мультимедийные файлы;
# * прочая техническая информация.
#
# >Адрес — это `URL`, Uniform Resource Locator (с англ. Унифицированный Указатель Ресурса).

# %% [markdown]
# ### МЕТОДЫ ЗАПРОСОВ В ПРОТОКОЛЕ HTTP
#
# Для того чтобы указать серверу на то, какое действие мы хотим произвести с ресурсом, в протоколе HTTP используются так называемые методы. В HTTP существует несколько методов, которые описывают действия с ресурсами. Чаще всего используются `GET` и `POST`.
#
# `GET` — ПОЛУЧЕНИЕ РЕСУРСА
#
# Метод `GET` запрашивает информацию из указанного источника и не может влиять на его содержимое. Запрос доступен для кэширования данных (то есть для сохранения, восстановления и дальнейшего использования) и добавления в закладки. Длина запроса ограничена (максимальная длина — 2048 символов).
#
# Пример `GET`-запроса, отправляемого через адресную строку браузера:
#
# >http://site.ru/page.php?name=dima&age=27
#
# `POST` — СОЗДАНИЕ РЕСУРСА
#
# Метод `POST` используется для отправки данных, которые могут оказывать влияние на содержимое ресурса. В отличие от метода GET, запросы POST не могут быть кэшированы, они не остаются в истории браузера и их нельзя добавить в закладки. Длина запроса POST не ограничивается.
#
# Пример `POST`-запроса, отправляемого через форму запроса:
#
# >POST / HTTP/1.0\r\n
# >
# >Host: www.site.ru\r\n
# >
# >Referer: http://www.site.ru/index.html\r\n
# >
# >Cookie: income=1\r\n
# >
# >Content-Type: application/x-www-form-urlencoded\r\n
# >
# >Content-Length: 35\r\n
# >
# >\r\n
# >
# >login=Dima&password=12345
#
# ### ДОПОЛНИТЕЛЬНО
#
# [Подробнее про методы HTTP](https://developer.mozilla.org/ru/docs/Web/HTTP/Methods)

# %% [markdown]
# ## 3. Библиотека requests <a class="anchor" id=3></a>
#
# [к содержанию](#0)
#
# В стандартной библиотеке Python для отправки веб-запросов существует функция `urllib2`, но большинство разработчиков используют стороннюю библиотеку `requests` (c англ. запросы), потому что её работа более стабильна, а созданный с её помощью код получается проще. Поэтому мы будем работать с библиотекой `requests`, а `urllib2` рассматривать не будем.
#
# Познакомимся с библиотекой `requests`, решив простую задачу — получить значения курсов валют. Курс валют — полезная и регулярно обновляемая информация, но каждый раз в ручном режиме получать информацию о курсе интересующей валюты трудоёмко.
#
# С помощью скрипта мы будем в удобном виде выгружать информацию по курсам валют с заранее выбранного сайта.
#
# >Один из сайтов в интернете, на котором информация о курсах валют дублирует информацию с сайта [Центрального Банка России](https://www.cbr.ru/), — ресурс [Курсы валют ЦБ РФ в XML и JSON](https://www.cbr-xml-daily.ru/). На данном ресурсе информация о курсах валют представлена в разных форматах, в том числе и в структурированном JSON-формате, методы работы с которым мы изучили в одном из предыдущих модулей.
#
# Перед началом работы библиотеку requests потребуется установить. Например, в Jupyter Notebook это делается с помощью такой команды:

# %%
import requests
# Определяем значение URL страницы для запроса
url = 'https://www.cbr-xml-daily.ru/daily_json.js' 
# Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ### РАБОТАЕМ С ОТВЕТОМ
#
# Мы сделали запрос и получили корректный ответ (код статуса — 200). Дальнейшую работу производим с результатом запроса к ресурсу Курсы валют ЦБ РФ в XML и JSON.
#
# >Как получить доступ ко всей информации, которую содержит ответ?
#
# Текст ответа хранится в атрибуте `text`. Выведем значение атрибута на экран и посмотрим на его содержимое:

# %%
print(response.text)
# Out:
# {
#     "Date": "2022-07-15T11:30:00+03:00",
#     "PreviousDate": "2022-07-14T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/07\/14\/daily_json.js",
#     "Timestamp": "2022-07-14T20:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 39.3641,
#             "Previous": 39.6322
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 34.2687,
#             "Previous": 34.4307
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 69.6402,
#             "Previous": 69.5831
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 14.1184,
#             "Previous": 14.2124
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 22.5531,
#             "Previous": 22.4977
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 29.986,
#             "Previous": 30.052
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 10.7903,
#             "Previous": 10.8159
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 14.2437,
#             "Previous": 14.3139
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 74.3451,
#             "Previous": 74.6965
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 10,
#             "Name": "Датских крон",
#             "Value": 78.8095,
#             "Previous": 78.994
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 58.2568,
#             "Previous": 58.5322
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 58.3432,
#             "Previous": 58.9002
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 73.7209,
#             "Previous": 73.7813
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 12.2411,
#             "Previous": 12.3647
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 44.8958,
#             "Previous": 44.9729
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 71.8333,
#             "Previous": 72.2874
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 10,
#             "Name": "Китайских юаней",
#             "Value": 86.3954,
#             "Previous": 87.2451
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 30.1747,
#             "Previous": 30.3631
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 56.8792,
#             "Previous": 57.5199
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 12.1073,
#             "Previous": 12.2148
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 11.8286,
#             "Previous": 11.8915
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 76.4318,
#             "Previous": 76.6614
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 41.7432,
#             "Previous": 41.6244
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 55.5424,
#             "Previous": 55.7992
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 33.4675,
#             "Previous": 33.8812
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 16.6448,
#             "Previous": 16.7235
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 53.2746,
#             "Previous": 53.5995
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 19.7724,
#             "Previous": 19.8089
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 24.0294,
#             "Previous": 23.9141
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 55.0091,
#             "Previous": 55.1795
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 59.186,
#             "Previous": 59.8
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 34.1935,
#             "Previous": 34.407
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 44.3997,
#             "Previous": 44.7871
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 42.2151,
#             "Previous": 42.6868
#         }
#     }
# }

# %% [markdown]
# Как правило, при работе над реальным проектом на этапе получения данных мы уже понимаем, с какими форматами данных нам придётся работать. На предлагаемом для работы ресурсе информация есть как в `JSON`-формате, так и в `XML`. По нашему запросу ресурс возвращает информацию в `JSON`-формате, однако в настоящий момент результат хранится как единая строка. Проверить тип данных полученного ответа можно, воспользовавшись функцией `type()`.
#
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь. В объект ответа `Response`  из библиотеки `requests` уже встроен метод `json()` .
#
# Импортируем функцию `pprint()`, применим к полученному ответу метод `json()` и выведем полученный результат на экран:

# %%
# Импортируем функцию pprint()
from pprint import pprint 
# Применяем метод json()
currencies = response.json() 
# Выводим результат на экран)
pprint(currencies)
# Out:
# {'Date': '2022-07-15T11:30:00+03:00',
#  'PreviousDate': '2022-07-14T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/07/14/daily_json.js',
#  'Timestamp': '2022-07-14T20:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 14.2124,
#                     'Value': 14.1184},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 39.6322,
#                     'Value': 39.3641},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 34.4307,
#                     'Value': 34.2687},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 30.052,
#                     'Value': 29.986},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 10.8159,
#                     'Value': 10.7903},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 22.4977,
#                     'Value': 22.5531},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 44.9729,
#                     'Value': 44.8958},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 59.8,
#                     'Value': 59.186},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайских юаней',
#                     'Nominal': 10,
#                     'NumCode': '156',
#                     'Previous': 87.2451,
#                     'Value': 86.3954},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 23.9141,
#                     'Value': 24.0294},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датских крон',
#                     'Nominal': 10,
#                     'NumCode': '208',
#                     'Previous': 78.994,
#                     'Value': 78.8095},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 58.9002,
#                     'Value': 58.3432},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 69.5831,
#                     'Value': 69.6402},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 74.6965,
#                     'Value': 74.3451},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 14.3139,
#                     'Value': 14.2437},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 73.7813,
#                     'Value': 73.7209},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 42.6868,
#                     'Value': 42.2151},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 72.2874,
#                     'Value': 71.8333},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 44.7871,
#                     'Value': 44.3997},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 12.3647,
#                     'Value': 12.2411},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 30.3631,
#                     'Value': 30.1747},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 57.5199,
#                     'Value': 56.8792},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 12.2148,
#                     'Value': 12.1073},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 11.8915,
#                     'Value': 11.8286},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 55.1795,
#                     'Value': 55.0091},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 41.6244,
#                     'Value': 41.7432},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 55.7992,
#                     'Value': 55.5424},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 16.7235,
#                     'Value': 16.6448},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 33.8812,
#                     'Value': 33.4675},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 19.8089,
#                     'Value': 19.7724},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 58.5322,
#                     'Value': 58.2568},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 53.5995,
#                     'Value': 53.2746},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 76.6614,
#                     'Value': 76.4318},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 34.407,
#                     'Value': 34.1935}}}

# %% [markdown]
# Теперь данные находятся в словаре и можно легко получать необходимые значения.
#
# Например, по ключу Valute мы можем обратиться к вложенному словарю, который содержит информацию о мировых валютах. Выведем на экран, например, информацию о евро (EUR):

# %%
pprint(currencies['Valute']['EUR'])
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 58.9002,
#  'Value': 58.3432}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ## 4. Парсинг сайтов <a class="anchor" id=4></a>
#
# [к содержанию](#0)
#
# >Ресурс, с которым мы работали в предыдущем юните, возвращал ответ о текущем курсе валют в удобном, структурированном формате, из которого было легко извлечь необходимую информацию. Довольно часто для получения информации приходится обращаться напрямую к `HTML`-страницам.
#
# Для примера рассмотрим страницу, содержащую [статью](https://nplus1.ru/news/2021/10/11/econobel2021) с информацией о присуждении Нобелевской премии по экономике в 2021 году, и попробуем извлечь из неё заголовок статьи, опубликованной на странице, дату публикации, а также текст статьи.
#
# Получить содержимое страницы в большинстве случаев несложно, гораздо труднее извлечь из `HTML`-кода нужную информацию.
#
# ? Что собой представляет `HTML`?
#
# ### ОСНОВЫ HTML
#
# `HTML` (англ. HyperText Markup Language, рус. язык гипертекстовой разметки) — стандартизированный язык разметки документов в интернете. Большинство веб-страниц содержат описание разметки на языке `HTML`. Язык `HTML` интерпретируется браузерами. Полученный в результате интерпретации текст отображается на экране монитора компьютера или мобильного устройства.
#
# `HTML` позволяет создавать макет страницы, разбивая её на блоки: мы можем поместить содержимое посередине страницы, сбоку и т. п.
#
# Кроме того, `HTML` используется для описания форматирования. Например, с его помощью мы можем указать, какая часть текста должна отображаться крупным шрифтом как заголовок, какая — курсивом, а какая — как обычный текст.
#
# `HTML` является близким родственником уже знакомого вам формата XML. Разметка на языке `HTML` делается с помощью так называемых тегов, которые помещаются в угловые скобки, и применяется к элементам, заключённым внутри них. Посмотрите на примеры:
#
# > `<h2> Это заголовок второго уровня </h2>`
# >
# > `<div> А это обычный текст </div>`
#
# У корректной `HTML`-страницы есть заголовок и тело страницы. В заголовке (в тегах `<head> … </head>`)  размещается техническая информация, подключаются скрипты и стили. В теле `<body> … </body>` находятся текст и данные, которые непосредственно отображаются на странице в браузере.
#
# Изучение языка HTML находится вне рамок этого курса, но для того, чтобы собирать информацию с веб-страниц, нет необходимости хорошо знать HTML. Достаточно понимать, что:
#
# - существуют теги с разными именами;
# - у тегов бывают атрибуты, такие как class и id;
# - теги образуют иерархическую структуру, то есть одни теги вложены в другие.
#
# ### ДОПОЛНИТЕЛЬНО
#
# Вы можете ознакомиться с информацией о HTML в справочнике, перейдя по [ссылке](http://htmlbook.ru/html).

# %% [markdown]
# ### ПОЛУЧАЕМ СОДЕРЖИМОЕ ВЕБ-СТРАНИЦЫ <a class="anchor" id=4-1></a>
#
# Получим HTML-код интересующей нас страницы.
#
# Для этого отправим GET-запрос с помощью библиотеки requests и метода get() и посмотрим на текст ответа на наш запрос (как мы помним, он содержится в атрибуте text):

# %%
# Импортируем библиотеку requests
import requests 
# Определяем адрес страницы
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' 
# Выполняем GET-запрос
response = requests.get(url)  
# Выводим содержимое атрибута text
print(response.text)
# Out:
# <!doctype html>
# <html class="old-town-road no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021" />
#
#     <link rel="icon" href="/i/favicon-bw.png" />
#
#
#         <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#
#     	    <meta itemprop="datePublished" content="2021-10-11"/>
#
# 	    <meta name="mediator_author" content="Илья Ферапонтов"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#         <meta name="author" content="Илья Ферапонтов" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021" />
#         <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#         <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#         <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1657039619">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1635965090">
#     <link rel="stylesheet" href="/js/tests/scopus/css/style.css">
#
#             <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#
#
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2021/10/11/econobel2021"},"headline":"Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей","description":"Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. ","image":"https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg","author":{"@type":"Person","name":"Илья Ферапонтов"},"publisher":{"@type":"Organization","name":"N + 1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2021-10-11"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
#
#
#
#
#
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
#
#
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
#
#
#
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2022/07/11/consumptive-chic" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/07/11/consumptive-chic" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Каролин Дей &laquo;Чахоточный шик. История красоты, моды и недуга&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/07/08/kolchaks-gold" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Олег Будницкий &laquo;Золото Колчака&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/07/06/food-without-fear" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Ручи Гупта &laquo;Аллергия, непереносимость, чувствительность&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/07/04/the-genes-that-make-us" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Эдвин Керк &laquo;Мальчик, который не переставал расти&hellip; и другие истории про гены и людей&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/07/01/the-french-language-in-russia" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дерек Оффорд, Владислав Ржеуцкий, Гезине Арджент &laquo;Французский язык в России&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/29/fashionopolis" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дана Томас &laquo;Fashionopolis: Цена быстрой моды и будущее одежды&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/27/tudes-galilennes" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Александр Койре &laquo;Этюды о Галилее&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/24/industrialization-and-empty-shelves" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Елена Осокина &laquo;За фасадом &quot;сталинского изобилия&quot;&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/06/22/the-earth-is-weeping" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Питер Коззенс &laquo;И будет рыдать земля: Как у индейцев отняли Америку&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2022/07/13/basic-economics" class="container-link active">
#         	        	<div class="heading"><span>Книжная полка</span></div>
#             	    	<div class="link"><span>Томас Соуэлл &laquo;Принципы экономики. Классическое руководство&raquo;</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="30917" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="economics" href="/rubric/economics">Экономика</a>
#                                                 <a data-theme="nobelprize" href="/theme/nobelprize">Нобелевская премия</a>
#                     </p>
#         <p class="table">
#             <a href="/news/2021/10/11">
#                 <time itemprop="datePublished" content="2021-10-11" data-unix="1633946665">
#                     <span>13:04</span>
#                     <span>11 Окт. 2021</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/1.1">
#                 <span>Сложность</span>
#                 <span class="difficult-value">1.1</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Илья Ферапонтов';
#         _dlData.custom_difficult = '1.1';
#         _dlData.custom_rubric.push('Экономика');
#                 _dlData.custom_theme = 'Нобелевская премия';
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg"/>
#                                                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Премия Шведского национального банка по&nbsp;экономическим наукам памяти Альфреда Нобеля за&nbsp;2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a>&nbsp;на&nbsp;официальном сайте Нобелевской премии.</p>
#
# <div class="incut incut-gallery " data-id="30917">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.</p>
#
#                                             	    <p class="credits">Niklas Elmehed © Nobel Prize Outreach</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Премия по&nbsp;экономике, в&nbsp;отличие от&nbsp;Нобелевских премий по&nbsp;физиологии и&nbsp;медицине, физике, химии и&nbsp;литературе, а&nbsp;также премии мира, была учреждена не&nbsp;самим Альфредом Нобелем, а&nbsp;Банком Швеции в&nbsp;1968&nbsp;году. Ее&nbsp;размер равен размеру остальных премий.<p>Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p><p>Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p><p>Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на&nbsp;основе наукометрических данных, в&nbsp;2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в&nbsp;экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и&nbsp;Дэвиду Тису (David Teece) за&nbsp;исследование инноваций.</p>
#
# <p>Кроме того, в&nbsp;списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а&nbsp;также Кармен Рейнхарт (Carmen Reinhart) и&nbsp;Кеннет Рогофф (Kenneth Rogoff)&nbsp;— авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90&nbsp;процентов от&nbsp;ВВП, скорость роста ВВП падает вдвое.</p>
#
# <p>В&nbsp;2020 году премию по&nbsp;экономике присудили Полу Милгрому и&nbsp;Роберту Уилсону за&nbsp;развитие теории аукционов и&nbsp;изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и&nbsp;разрабатывали новые форматы проведения аукционов для продажи товаров и&nbsp;услуг, которые трудно продавать с&nbsp;помощью традиционных методов. Читайте об&nbsp;их&nbsp;работах в&nbsp;нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p>
#
# <p>В 2019 году премии памяти Нобеля по&nbsp;экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и&nbsp;Майкл Кремер&nbsp;— «за&nbsp;экспериментальный подход к&nbsp;искоренению глобальной бедности». Подробнее о&nbsp;заслугах лауреатов можно прочесть в&nbsp;нашем материале&nbsp;<a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на&nbsp;бедных»</a>. В&nbsp;2018 года награда была присуждена Уильяму Нордхаусу за&nbsp;«интеграцию изменения климата в&nbsp;долгосрочный макроэкономический анализ» и&nbsp;Полу Ромеру за&nbsp;«интеграцию технологических инноваций в&nbsp;долгосрочный макроэкономический анализ». Об&nbsp;их&nbsp;работах можно прочитать в&nbsp;материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p>
#
# <p><i>Сергей Кузнецов</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                 <meter class="top"></meter>
#
#
#
#
#                     <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/mLOY-and-heart-failure" data-id="33561" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2022/07/14/24ccca5df93dbb087d4d31eea9852964.gif"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2022-07-14">вчера</span>
#                         </div>
#                         <h3>Потеря Y-хромосомы привела к болезням сердца у самцов мышей</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/ht-aero" data-id="33557" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-07-14">вчера</span>
#                 </div>
#
#                                     <h3>Китайцы показали испытания аэротакси с автомобильным рулем</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/ancient-dna" data-id="33551" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-07-14">вчера</span>
#                 </div>
#
#                                     <h3>14000-летний архаичный череп из Китая оказался сапиентным</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/Anti-reflection" data-id="33559" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-07-14">вчера</span>
#                 </div>
#
#                                     <h3>Антиотражающий слой сделал мутную среду прозрачной</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/water-goddess" data-id="33554" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-07-14">вчера</span>
#                 </div>
#
#                                     <h3>Археологи обнаружили в доисторической канаве статуэтку богини воды</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#                             <!-- ba3 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <низ страницы>-->
# <div id="adfox_154408219501673625"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push([{
#         ownerId: 248569,
#         containerId: 'adfox_154408219501673625',
#         params: {
#             pp: 'i',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['desktop', 'tablet'], {
#         tabletWidth: 830,
#         isAutoReloads: false
#     }]);
# })(window, 'adfoxAsyncParamsAdaptive');
# </script>
#
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/13/tasmola" data-id="33541" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/07/13/b25fa64653606a8687eaea14e3b192b1.jpeg)" class="ill"></div>
#
#
#
#                                     <h3>Древний кочевник из Казахстана выжил после ранения бронзовым наконечником в позвонок</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/proterozoic-geodynamo" data-id="33552" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/07/14/7d01b9048d28cbde24910640fef0a577.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Скачок магнитного поля 1,1 миллиарда лет назад указал на солидный возраст внутреннего ядра Земли</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/07/14/no-obesity-no-headache" data-id="33550" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/07/13/169207a32a16ff159e9606055a5ecb1b.gif)" class="ill"></div>
#
#
#
#                                     <h3>Лекарство от мигрени помогло мышам справиться с ожирением</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2022/07/13/6d68d4a7c1d85c89cb4dc250127b9529.jpg" style=background-image:url(https://nplus1.ru/images/2022/07/13/bc08283403b3122d1e5b0c0a5887b6c8.jpg)>
#
#     <a href="/material/2022/07/14/jwst-photos" data-id="33539" >
#         <div class="caption">
#                                                                                     <h3>Посмотреть инфракрасным глазом</h3>
#                     <p class="subtitle">Телескоп &laquo;Джеймс Уэбб&raquo; начал научную программу</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/astronomy">Астрономия</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="ign8gNCjU4GenlkJnRrjXN2Xq8PoGoa54qPF9u2p">
#         <input type="hidden" name="id_news" value="30917">
#         <input type="hidden" name="id_author" value="120">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="ign8gNCjU4GenlkJnRrjXN2Xq8PoGoa54qPF9u2p">
#         <input type="hidden" name="id_news" value="30917">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/11/interstellar-quantum-communication">Теоретики разрешили квантовую коммуникацию на межзвездных расстояниях</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/06/electron-vortices">Физики напрямую увидели электронные вихри</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/04/X-ray-helical-dichroism">Хиральность молекул увидели с помощью закрученного рентгена</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2022/07/05/fields2022">Отличники</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/07/ORGAN-phase1a">Галоскоп ORGAN не нашел аксионов массой от 63 до 67 микроэлектронвольт</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/13/interest-change-in-stack-overflow">Программисты поменяли интересы как ученые</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/07/strychnine-biosynthesis">Химики разгадали путь биосинтеза стрихнина и воспроизвели его в табаке</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/05/1-pentaquark-2-tetraquarks">Физики открыли пентакварк и два тетракварка одновременно</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/04/plant-boolean">Генетики научили клетки растений выполнять логические операции</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/07/06/deepmind">Алгоритм от DeepMind научился распределять деньги инвесторов по справедливости</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/blog/2022/04/01/samotek">Авторам</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2022 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                                         </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                                         <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
# <script src="/js/tests/scopus/js/bundle.js"></script>
#
#
# <script>$(function(){$('html').removeClass('old-town-road')})</script>
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1657552540"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# Ответ содержит `HTML`-код страницы, к которой мы обратились.
#
# В отличие от предыдущего примера, где ответ возвращался в `JSON`-формате, мы не можем так просто преобразовать `HTML`-код в словарь и извлечь необходимую нам информацию.
#
# Для решения таких задач в Python существует специальная библиотека `BeautifulSoup`, о работе с которой мы поговорим в следующем юните.

# %% [markdown]
# ## 5. Библиотека BeautifulShop <a class="anchor" id=5></a>
#
# [к содержанию](#0)
#
# Для поиска необходимых нам данных мы будем использовать библиотеку `BeautifulSoup`, которая позволяет по названию тегов и их атрибутов получать содержащийся в них текст.
#
# `BeautifulSoup` не является частью стандартной библиотеки, поэтому для начала её нужно установить. Например, в Jupyter Notebook это делается с помощью такой команды:

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Теперь мы можем извлекать данные из любой веб-страницы.
#
# Ранее мы уже получили содержимое страницы с помощью `GET`-запроса и сохранили информацию в переменной `response` , теперь создадим объект `BeautifulSoup` с именем `page`, указывая в качестве параметра `html.parser`.
#
# Для примера получим информацию o `title` (с англ. заголовок) — это строка, которая отображается на вкладке браузера:

# %%
# Определяем адрес страницы
url = 'https://nplus1.ru/news/2021/10/11/econobel2021'
# Выполняем GET-запрос, содержимое ответа присваивается переменной response
response = requests.get(url)
# Создаём объект BeautifulSoup, указывая html-парсер
page = BeautifulSoup(response.text, 'html.parser') 
# Получаем тег title, отображающийся на вкладке браузера
print(page.title) 
# Выводим текст из полученного тега, который содержится в атрибуте text
print(page.title.text)
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ### ИЗВЛЕКАЕМ ЗАГОЛОВОК И ВРЕМЯ НАПИСАНИЯ СТАТЬИ
#
# Выполним поставленную ранее задачу: получить информацию о странице и извлечь заголовок [статьи](https://nplus1.ru/news/2021/10/11/econobel2021), опубликованной на этой странице, дату публикации, а также текст статьи.
#
# Предположим, что мы знаем, что в `HTML`-коде рассматриваемой нами страницы заголовок статьи заключён в тег `<h1> … </h1>` (заголовок первого уровня).
#
# Тогда мы можем получить его текст с помощью метода `find()` (с англ. найти) объекта `BeautifulSoup`, передав ему название интересующего нас тега:

# %%
# Применяем метод find() к объекту и выводим результат на экран
print(page.find('h1').text)
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# Проще всего это сделать с помощью так называемого инструмента разработчика, который есть во всех современных браузерах. Покажем, как открыть данный инструмент на примере использования браузера Google Chrome.
#
# Устанавливаем курсор на элементе страницы (заголовок статьи), информацию о котором хотим получить, нажимаем на правую клавишу мыши и в выпадающем списке выбираем пункт **Посмотреть код./Исследовать элемент**
#
# <img src=p_17_img2.png>
#
# Итак, нам нужен тег `<time> … </time>`.
#
# Теперь получим данные из него с помощью уже известного метода `find()`, передав название нужного тега:

# %%
# Выводим на экран содержимое атрибута text тега time
print(page.find('time').text)
# Out:
# 13:04
# 11 Окт. 2021

# %%
# 5.4 Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.
def wiki_header(url):
    response = requests.get(url)
    page = BeautifulSoup(response.text, 'html.parser')
    print(page.find('h1').text)
    
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# Operating system

# %% [markdown]
# ### НЕУНИКАЛЬНЫЕ ТЕГИ: ИЗВЛЕКАЕМ ТЕКСТ СТАТЬИ
#
# Теперь получим сам текст статьи. Как вы уже знаете, первым делом необходимо определить, в какой тег он заключён. Применим, как и ранее, инструмент разработчика.
#
# <img src=p_17_img3.jpg>
#
# Видим, что искомый текст заключён в тег  `<div> … </div>` . Попробуем извлечь его уже известным нам способом — с помощью метода `find()` — и выведем его на экран.

# %%
# Определяем адрес страницы
url = 'https://nplus1.ru/news/2021/10/11/econobel2021'
# Выполняем GET-запрос, содержимое ответа присваивается переменной response
response = requests.get(url)
# Создаём объект BeautifulSoup, указывая html-парсер
page = BeautifulSoup(response.text, 'html.parser') 

print(page.find('div').text)

# %% [markdown]
# Мы увидели не то, что ожидали — пустое содержимое...
#
# В чём же проблема?
#
# Дело в том, что теги `<div> … </div>` очень распространённые и на странице их очень много. Метод `find()` нашёл первый из них, но это не то, что нам надо.
#
# Посмотрим на нашу страницу, используя инструмент разработчика, ещё раз. Можем заметить, что у искомого текста есть свой класс — `body js-mediator-article` :
#
# <img src=p_17_img4.jpg>
#
# Передадим название класса в метод `find()` с помощью аргумента `class_` и получим текст статьи:

# %%
print(page.find('div', class_='body').text) # Выводим содержимое атрибута text тега div класса body js-mediator-article
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.
#
#
#
#
#
#
#
#
#
# Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.
# Niklas Elmehed © Nobel Prize Outreach
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году предположила, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.
# Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.
# В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале «Тонкости молотка».
# В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале «Опыты на бедных». В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале «Почем знания для природы».
# Сергей Кузнецов

# %% [markdown]
# В данном случае происходит поиск точного строкового значения class атрибута, т. е. выполнение строк кода:
#
# <img src=p_17_img5.png>
#
# даст одинаковый результат.
#
# ### Дополнительно
#
# О поиске по классу можно узнать подробнее в [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class).

# %% [markdown]
# [к содержанию](#0)
#
# ### СБОР НЕСКОЛЬКИХ ЭЛЕМЕНТОВ: СОБИРАЕМ ВСЕ ССЫЛКИ НА СТРАНИЦЕ <a class="anchor" id=5-1></a>
#
# Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в [Wikipedia](https://en.wikipedia.org/wiki/List_of_programming_languages) в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег `<a> … </a>`. Попробуем использовать `find()`:

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %% [markdown]
# Мы получили **только одну ссылку**, хотя на странице их явно больше.
#
# Это происходит, потому что метод `find()` возвращает только **первый подходящий элемент**. Если требуется получить больше элементов, необходимо воспользоваться методом `find_all()` (с англ. найти все):

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 938

# %% [markdown]
# Итак, на момент создания этих учебных материалов на странице содержалось 928 ссылок. Посмотрим на некоторые из них:

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['OpenCL', 'OpenEdge Advanced Business Language', 'OpenVera', 'OpenQASM', 'OPS5', 'OptimJ', 'Orc', 'ORCA/Modula-2', 'Oriel', 'Orwell']

# %% [markdown]
# Не все ссылки соответствуют названиям языков программирования — страница содержит также **«служебные»** ссылки, такие, например, как `Jump to navigation` (с англ. Перейти к навигации) или `Alphabetical` (с англ. По алфавиту):

# %%
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['', 'Jump to navigation', 'Jump to search', 'Programming languagelists', 'Alphabetical', 'Categorical', 'Chronological', 'Generational', 'v', 't']

# %% [markdown]
# В заключение заметим, что `BeautifulSoup` — достаточно мощная библиотека. Мы рассмотрели её базовые возможности, но их полный список гораздо шире. С ним можно ознакомиться в [официальной документации](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).

# %% [markdown]
# ## 6. Работа с API <a class="anchor" id=6></a>
#
# [к содержанию](#0)
#
# В предыдущих разделах мы собирали полезную информацию с различных сайтов.
#
# Вы могли убедиться, что поиск необходимой информации с выделением правильных тегов — довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка или владельцы сайтов защищаются от ботов **капчей**.
#
# К счастью, многие крупные сайты предоставляют доступ к так называемым `API` (англ. Application Programming Interface, рус. Интерфейс Прикладного Программирования).
#
# >`API` — это специальные разделы сайта, где информацию можно получать без разметки, а формат запросов и ответов зафиксирован. `API` созданы для того, чтобы облегчить взаимодействие с сайтом для сторонних разработчиков.
#
# К примеру, мы уже видели, как ресурс [Курсы валют ЦБ РФ](https://www.cbr-xml-daily.ru/) в `XML` и `JSON` возвращает данные о валютах в JSON-формате. Это пример `API`.
#
# Рассмотрим на примере социальной сети ВКонтакте особенности `API`, характерные для более крупных сайтов.
#
# ### КЛЮЧ АВТОРИЗАЦИИ
#
# Для того чтобы начать работать с `API`, обычно необходимо получить сервисный ключ авторизации — **токен**.
#
# >Токен — это средство идентификации пользователя или отдельного сеанса работы в компьютерных сетях и приложениях. Различают программные и аппаратные токены.
# Мы будем использовать программный токен, который обычно представляет собой зашифрованную последовательность символов, позволяющую точно идентифицировать объект и определить уровень его привилегий. Он генерируется системой авторизации и привязывается к конкретному сеансу работы, клиенту сети или пакету данных.
#
# Авторизация применяется практически во всех `API`, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени.
#
# Сервисный токен для `API` ВКонтакте для нашей задачи создаётся вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на [страницу](https://vk.com/editapp?act=create), чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и в разделе **Платформа** поставьте отметку выбора напротив значения **Standalone**-приложение:
#
# <img src=p_17_img7.png>
#
# Подтвердив создание приложения на сайте в приложении ВКонтакте или по СМС, зайдите в Настройки. Нужный нам токен лежит в поле Сервисный ключ доступа:
#
# <img src=p_17_img8.jpg>

# %% [markdown]
# ### ПЕРВЫЕ ЗАПРОСЫ К API <a class="anchor" id=6-1></a>
#
# [к содержанию](#0)
#
# Чтобы познакомиться с работой API, мы будем получать данные для статистических отчётов произвольной группы, например данные о соотношении мужчин и женщин, статистику географии пользователей и т. п.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Сделаем наш первый запрос из браузера.
#
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова TOKEN ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:
#
# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=TOKEN
#
# Вывод:
#
# <img src=p_17_img9.jpg>
#
# Итак, мы сделали `GET`-запрос к `API` ВКонтакте, который состоит из следующих элементов:
#
# - `https://api.vk.com/method `— домен и `URL` запроса `API`; обычно не меняется;
# - `users.get` — название метода, который отдаёт определённый отчёт, в нашем случае это метод для получения информации о пользователе;
# - `user_id и v` — параметры запроса: идентификатор пользователя, о котором хотим получить информацию (в нашем примере мы запрашиваем информацию о первом пользователе), и номер версии `API`;
# - `token` — токен, который выдаётся только пользователям, имеющим право просматривать определённые данные, например показания счётчиков Яндекс.Метрики вашего проекта; на все остальные запросы без корректного токена система отвечает отказом.
#
# Если мы обратимся к документации метода `users.get`, то увидим, что в ней описано множество других параметров, которые можно получить о пользователе (дата рождения, пол, родной город и другие) — словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал).
#
# Добавим к запросу **дату рождения и пол** (согласно документации, эти параметры надо перечислять в поле `fields`):
#
# <img src=p_17_img10.jpg>
#
# До этого момента мы делали запросы в браузере — теперь давайте выполним запросы из кода.

# %% [markdown]
# ### ЗАПРОС К API ИЗ КОДА <a class="anchor" id=6-2></a>
#
# [к содержанию](#0)
#
# Продолжаем пользоваться всё той же библиотекой `requests`.

# %%
import requests # Импортируем модуль requests
token = '443453d1443453d1443453d1a24449394b44434443453d126e4bff5672cf2a4ff2753d9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# Мы получили строку в `JSON`-формате, которую можно преобразовать в словарь с помощью метода `json()`, после чего можно с лёгкостью обращаться к различным полям.
#
# Словари нагляднее выводить с помощью функции `pprint()`, которую мы уже использовали ранее:

# %%
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
# 6.1 Напишите строку кода, которая выведет на экран имя пользователя:
print(user['first_name'])
# Out:
# Павел

# %% [markdown]
# Метод `users.get()` позволяет запрашивать информацию **о множестве (до 1 000)** пользователей одновременно. Для этого нужно использовать параметр `user_ids` и передавать `id` через запятую в строковом формате. Например, чтобы получить информацию о пользователях с `id=1`, `id=2`, `id=3`, необходимо передать значение параметра u`ser_ids='1,2,3'`.
#
# Попробуем это сделать:

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %%
# 6.2 Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. 
# Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе. 
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.
import pandas as pd
ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых 500 пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
jsom_file = requests.get(url, params=params).json()
df = pd.DataFrame(jsom_file['response'])
display(df['sex'].value_counts())
print('Процент женщин',round(df[df['sex'] == 1].shape[0] / (df[df['sex'] == 1].shape[0] + df[df['sex'] == 2].shape[0]),2))
print('Процент мужчин',round(df[df['sex'] == 2].shape[0] / (df[df['sex'] == 1].shape[0] + df[df['sex'] == 2].shape[0]),2))
# Out:
# 2    217
# 1    205
# 0     78
# Name: sex, dtype: int64
# Процент женщин 0.49
# Процент мужчин 0.51

# %% [markdown]
# ### СБОР ИНФОРМАЦИИ ИЗ ГРУПП <a class="anchor" id=6-3></a>
#
# [к содержанию](#0)
#
# В одном из предыдущих юнитов в качестве примера мы собрали информацию о небольшом количестве пользователей. Теперь перейдём к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# >Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
# >
# >- не учитываются все особенности вашего проекта;
# >- используется фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# >- не всегда бесплатны и вряд ли позволят работать с большими объёмами данных.
#
# Теперь мы научимся считать произвольные метрики групп, собирая данные из `API` и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# - ограничение на количество вызовов в единицу времени;
# - ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы [https://vk.com/vk](https://vk.com/vk) социальной сети ВКонтакте.
#
# Обратимся к [документации](https://vk.com/dev/groups), чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод [groups.getMembers](https://vk.com/dev/groups.getMembers).
#
# Согласно документации, обязательным параметром данного метода является `group_id` — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
import requests # Импортируем модуль requests
token = '443453d1443453d1443453d1a24449394b44434443453d126e4bff5672cf2a4ff2753d9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 12706254, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4189, 4192, 4236, 4262, 4282, 4326, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5527, 5546, 5547, 5585, 5590, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7408, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8910, 8937, 8959, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9399, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10155, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11568, 11649, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12821, 12859, 12892, 12922, 12932, 12952, 12957, 12982, 13008, 13063, 13080, 13173, 13224, 13233, 13248, 13324, 13357, 13371, 13401, 134 ...

# %% [markdown]
# По ключу `count` мы можем получить общее число участников группы, а список по ключу `items` хранит их id. Посмотрим на него поближе:

# %%
print(len(data['response']['items']))
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре `count`, это максимум, который может отдать **`API` за один раз.**
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром `offset` (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (`count` будет всегда равен 1000), увеличивая смещение `offset` на величину `count`.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением `count=5.` Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Теперь используем `count` и `offset`, чтобы получить те же `id` по пять за раз:

# %%
import requests # Импортируем модуль requests
token = '443453d1443453d1443453d1a24449394b44434443453d126e4bff5672cf2a4ff2753d9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Cпособ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив `count = 1000` и `max_count = data['response']['count']`.

# %% [markdown]
# ### ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ <a class="anchor" id=6-4></a>
#
# [к содержанию](#0)
#
# В `API` часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# >Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой `time` и методом `sleep`, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = '443453d1443453d1443453d1a24449394b44434443453d126e4bff5672cf2a4ff2753d9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ### ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ
#
# Через `API` новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в `API` ВКонтакте предусмотрен метод [wall.get](https://vk.com/dev.php?method=wall.get). Применим его:

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = '443453d1443453d1443453d1a24449394b44434443453d126e4bff5672cf2a4ff2753d9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 499,
#               'items': [{'attachments': [{'photo': {'access_key': '720e171a5115a08c28',
#                                                     'album_id': -7,
#                                                     'date': 1657189899,
#                                                     'id': 457332523,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1307907,
#                                                     'sizes': [{'height': 70,
#                                                                'type': 's',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=75x70&quality=95&sign=16604c19eba46c485b88db602edf0d16&c_uniq_tag=9arKyoONH6coX0vzesNyYjrcrEiyKJxhYxsqRQqDnsE&type=album',
#                                                                'width': 75},
#                                                               {'height': 122,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=130x122&quality=95&sign=24edd945412f0ba74d22f78bd921cafb&c_uniq_tag=CBCb4M-0Z0Zd87PubtZVfNcxTpoep7trbFCFwaJtTkU&type=album',
#                                                                'width': 130},
#                                                               {'height': 566,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=604x566&quality=95&sign=e75e8ea0188ffebe303863cb8ca725be&c_uniq_tag=iBIxBmouJBnwbQb791lVdWapYEbrb7vMwG1MGewMHuE&type=album',
#                                                                'width': 604},
#                                                               {'height': 757,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=807x757&quality=95&sign=5f2095b713bd52a983c90cb82b4f3e65&c_uniq_tag=DHU_-GPiJ8-SN-F-1bgpL89t_TyO-yezSogn-wHXxHo&type=album',
#                                                                'width': 807},
#                                                               {'height': 1200,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=1280x1200&quality=95&sign=aafd61122ec205ddef7923ec990d1105&c_uniq_tag=TRivw_rhiRzsl9kY5bvrQ2HKbpStYxZyRbzBTt-IRfU&type=album',
#                                                                'width': 1280},
#                                                               {'height': 2157,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=2300x2157&quality=95&sign=51cbfd2e2a00bbf48aa15250c19d6407&c_uniq_tag=cV4EAI-zDGyqTqoNrgWsOKaXpFAuarPROwDiteZ9-hg&type=album',
#                                                                'width': 2300},
#                                                               {'height': 122,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=130x122&quality=95&sign=24edd945412f0ba74d22f78bd921cafb&c_uniq_tag=CBCb4M-0Z0Zd87PubtZVfNcxTpoep7trbFCFwaJtTkU&type=album',
#                                                                'width': 130},
#                                                               {'height': 188,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=200x188&quality=95&sign=110b9cab5508bd78e553b7c7268965d3&c_uniq_tag=Q-TDYnegB0m5RlaU4OjwKHpVhzOz4__3vafu1sPWwp8&type=album',
#                                                                'width': 200},
#                                                               {'height': 300,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=320x300&quality=95&sign=da496ba9298bf71306da4f0328e34928&c_uniq_tag=3TSdyVY3DjtkFJuNG_PL8HjwIAiOwsLV9jSTNrBvud0&type=album',
#                                                                'width': 320},
#                                                               {'height': 478,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=510x478&quality=95&sign=dc633b02b188d87f86ead99e2aa7527d&c_uniq_tag=T3w2q0CCMIAnxgr5CLb86BP-FvdRcZ00ZIg9ktsIplc&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 488,
#                                       'groups_can_post': True},
#                          'date': 1657189899,
#                          'from_id': -22822305,
#                          'hash': 'Ye-Zxv4tJtTueWYWtw',
#                          'id': 1307907,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1875,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 629, 'user_reposted': 0},
#                          'text': 'Наверняка вам хоть раз писали неизвестные '
#                                  'люди. Теперь приложение ВКонтакте будет '
#                                  'предупреждать, если к собеседнику стоит '
#                                  'отнестись с осторожностью. \n'
#                                  '\n'
#                                  'В новом групповом чате или беседе с '
#                                  'незнакомым человеком наша система определит '
#                                  'возможного спамера и покажет специальное '
#                                  'уведомление прямо в переписке. Из него вы '
#                                  'сможете отправить жалобу и добавить '
#                                  'пользователя в чёрный список. Диалог или чат '
#                                  'в этом случае будут удалены. Так и другие '
#                                  'участники не перейдут по опасным ссылкам.',
#                          'views': {'count': 699513}},
#                         {'attachments': [{'link': {'caption': 'vc.ru',
#                                                    'description': 'Связываем '
#                                                                   'опыт и '
#                                                                   'оценки '
#                                                                   'юзеров с '
#                                                                   'техническими '
#                                                                   'метриками и '
#                                                                   'рассказываем, '
#                                                                   'как '
#                                                                   'устроена '
#                                                                   'архитектура '
#                                                                   'видеоплатформы.',
#                                                    'photo': {'album_id': -28,
#                                                              'date': 1657185416,
#                                                              'id': 457397598,
#                                                              'owner_id': 2000043330,
#                                                              'sizes': [{'height': 480,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun9-45.userapi.com/impg/RyF1Izql4869xJOCTCqlpYQsfzpJKb1EuELSIA/U8_9pKINCjg.jpg?size=1074x480&quality=96&sign=76fe19faae16e5478a546c3cc2c2d843&c_uniq_tag=UmgkKsNNc_Qh1gfUDzENOcaJJeziheNq-JvhWZemSkQ&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun9-45.userapi.com/impg/RyF1Izql4869xJOCTCqlpYQsfzpJKb1EuELSIA/U8_9pKINCjg.jpg?size=537x240&quality=96&sign=ba2f4b51f419f5d54221a21b28a2a831&c_uniq_tag=tYdDwG35m-Gx1fQH04iLjvsLj4l2UDAWTtYiRnxSgN0&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 70,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun9-45.userapi.com/impg/RyF1Izql4869xJOCTCqlpYQsfzpJKb1EuELSIA/U8_9pKINCjg.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=dc879da5f07da8522326cec8c2e51437&c_uniq_tag=GdsIxxRFNDtVkajbzDPelptvVaTuJ1pWO7GLhdZ3WAw&type=share',
#                                                                         'width': 130},
#                                                                        {'height': 140,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun9-45.userapi.com/impg/RyF1Izql4869xJOCTCqlpYQsfzpJKb1EuELSIA/U8_9pKINCjg.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=e6d09cd44225f682c6508d59b55edd20&c_uniq_tag=76GdKx0qE1ZKbJ8zZTnSv3kmlAVyEEM2wUAmE4z2DzM&type=share',
#                                                                         'width': 260},
#                                                                        {'height': 35,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun9-45.userapi.com/impg/RyF1Izql4869xJOCTCqlpYQsfzpJKb1EuELSIA/U8_9pKINCjg.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=9409300ce1a88a60872029f117a79bee&c_uniq_tag=Iy_37G7XJ5EKcS6o0Y7T5Ob8E_r534RdDoFoM9KCPpU&type=share',
#                                                                         'width': 75},
#                                                                        {'height': 80,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun9-45.userapi.com/impg/RyF1Izql4869xJOCTCqlpYQsfzpJKb1EuELSIA/U8_9pKINCjg.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=a4adf8837aa7fac3ecb3ff60ee8e0398&c_uniq_tag=Isark12HO3uw9ZG0qeOLoVv-FLUoECczaa0A1R7FA-Q&type=share',
#                                                                         'width': 150}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Как счастье '
#                                                             'пользователей '
#                                                             'помогает VK Видео '
#                                                             'улучшать сервис',
#                                                    'url': 'https://vc.ru/vk/456505-kak-schaste-polzovateley-pomogaet-vk-video-uluchshat-servis'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 111,
#                                       'groups_can_post': True},
#                          'date': 1657185907,
#                          'from_id': -22822305,
#                          'hash': 'Y8GT_5P1ia2_qmdJUw',
#                          'id': 1307837,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 607,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 232, 'user_reposted': 0},
#                          'text': 'Что внутри у VK Видео? Рассказали в блоге на '
#                                  'VC о главном принципе и секретах '
#                                  'видеоплатформы с 2,45 млрд просмотров в '
#                                  'сутки и 4 Тбит/с трафика. Подробно, но без '
#                                  'технических сложностей: vk.cc/ceVzb8\n'
#                                  '\n'
#                                  'В статье показываем, как анализируем ваши '
#                                  'оценки и развиваем сервис, опираясь на '
#                                  'обратную связь. Например, как делаем так, '
#                                  'чтобы видео не заставляло ждать перед '
#                                  'стартом, а в рекомендациях не показывалось '
#                                  'пять роликов о футболе подряд. Или почему '
#                                  'можно не бояться, что загрузка прервётся, '
#                                  'когда заливаете на платформу файл на сотню '
#                                  'гигабайт.\n'
#                                  '\n'
#                                  'Ещё поясняем, как работает наш готовый набор '
#                                  'технологий для любых сервисов с видео. Если '
#                                  'задумываетесь о таком проекте, оцените, что '
#                                  'можно потестировать и взять себе.',
#                          'views': {'count': 243144}},
#                         {'attachments': [{'photo': {'access_key': '8716afbe1697d20df0',
#                                                     'album_id': -7,
#                                                     'date': 1656684761,
#                                                     'id': 457332430,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1307005,
#                                                     'sizes': [{'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=75x42&quality=95&sign=9d1c5bca8ea76ebfef74a69d3bb1a24b&c_uniq_tag=olPGHlXhWfPtLTDc8q8UzpyVEBclNjsHdmsJirWItRQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 73,
#                                                                'type': 'm',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=130x73&quality=95&sign=0d64d02ef3184acbbf2b06eea0d3c698&c_uniq_tag=GyfbPPiY8cXZLEuOUQBovYpak_92nkBvWMgO195gDX0&type=album',
#                                                                'width': 130},
#                                                               {'height': 340,
#                                                                'type': 'x',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=604x340&quality=95&sign=909208792b8ae92b23b2f780264c4c81&c_uniq_tag=WRG0lGZVdPDIagoYV_NEH0eP0tko-TxGLywWpN97ZFY&type=album',
#                                                                'width': 604},
#                                                               {'height': 454,
#                                                                'type': 'y',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=807x454&quality=95&sign=11e15adc1a4107379c06cb9dc80970cc&c_uniq_tag=t8To5N3BgeT2o8PaIWjWIkYwPwk8G_yqpJ6MnKcJIfM&type=album',
#                                                                'width': 807},
#                                                               {'height': 720,
#                                                                'type': 'z',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=1280x720&quality=95&sign=69cbdf4d941eb3150c91d4532d3bc045&c_uniq_tag=abml-Ra7blux0QeN96OuI7BOWkAWnhHHrILmrKkrqts&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1080,
#                                                                'type': 'w',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=1920x1080&quality=95&sign=c272502e6f56e73daa33f6c3b07bf61f&c_uniq_tag=4GcHYeDtSv9VwHt6Gv3OU71SPeRZGmdkfMyM4GiR9rc&type=album',
#                                                                'width': 1920},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=130x87&quality=95&crop=153,0,1614,1080&sign=6472d688f10e6ac0ea5bd0c2e0f1a146&c_uniq_tag=BDheA4gkaKMyIETdAXftOCc6ku9-jLJ57KJHKKiKArY&type=album',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=200x133&quality=95&crop=148,0,1624,1080&sign=7e270f54647b669d631fd53f3094c660&c_uniq_tag=L6E-Qk-KqJ9KAsnueJxDJSYEcEbJ7r9GzuZbuhwQ-hI&type=album',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=320x213&quality=95&crop=148,0,1623,1080&sign=068d7db2e5afa2f51bb97f13c7b3642a&c_uniq_tag=SElG7_bJLKTuEJV6bTMTYyWPNjdNDUCFBAWb1qLbgvo&type=album',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/JGymC4hndN9DRzo1Kmevcjt-kfwj-cO2IJWsag/vok-z0iKTIU.jpg?size=510x340&quality=95&crop=150,0,1620,1080&sign=290b4d7f37815fe7cae312b6cdd11869&c_uniq_tag=w1VhCnDZfIw1VVgc5r-ZPxq_odURW9dDelwOKg2d9rU&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 361,
#                                       'groups_can_post': True},
#                          'date': 1656684843,
#                          'from_id': -22822305,
#                          'hash': 'EFEw9RSjPR4ytaYu-g',
#                          'id': 1307005,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 777,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 344, 'user_reposted': 0},
#                          'text': 'Собрали в обзоре главные июньские новинки — '
#                                  'заглядывайте, чтобы ничего не упустить: '
#                                  'vk.cc/ceNHnj.\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/dijest_june?anchor=video|В '
#                                  'разделе «Мои видео»] появилась история '
#                                  'просмотров, а при загрузке длинных записей '
#                                  'теперь можно добавлять тайм-коды.\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/dijest_june?anchor=klipy|Лента '
#                                  'VK Клипов] теперь мгновенно перестраивается '
#                                  'под ваши интересы и реакции — благодаря '
#                                  'новой системе рекомендаций.\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/dijest_june?anchor=servisy|Сервис '
#                                  '«Женский дневник»] поможет вести личный '
#                                  'календарь цикла и следить за самочувствием.\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/dijest_june?anchor=servisy|Чат-бот '
#                                  'для помощи в поисково-спасательных работах]: '
#                                  'записаться в добровольцы, получить помощь и '
#                                  'инструкции можно в переписке с сообществом '
#                                  'отряда «ЛизаАлерт».\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/dijest_june?anchor=programmy-podderzhki|Для '
#                                  'начинающих стримеров открыта программа '
#                                  'поддержки] — с продвижением на нашей '
#                                  'платформе и консультациями от экспертов.\n'
#                                  '\n'
#                                  '✅ '
#                                  '[https://vk.com/blog/dijest_june?anchor=muzyka|В '
#                                  'VK Музыке эксклюзивно доступен '
#                                  'трибьют-альбом] «Мы вышли из кино 2» — '
#                                  'слушайте хиты Виктора Цоя в исполнении '
#                                  'молодых инди-артистов.\n'
#                                  '\n'
#                                  'А в финале дайджеста — анонс новинки, '
#                                  'которая будет уникальной для каждого. '
#                                  'Подробности уже в блоге 👇',
#                          'views': {'count': 292928}},
#                         {'attachments': [{'photo': {'access_key': '5c66dabe76245036f3',
#                                                     'album_id': -7,
#                                                     'date': 1653638060,
#                                                     'id': 457331780,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=75x75&quality=95&sign=3d077ebd4bff68908de0c21695a903d3&c_uniq_tag=Z4qucqXMKu51B98bo-GA-HnMq5Ofi8mml29v7KflglQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=130x130&quality=95&sign=79497116fc76c449e6ebedb32f206c69&c_uniq_tag=2xuzJzQCcYpQCTgNiCQjKNfRmnmkdbnns0Jn6Hn2b34&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=604x604&quality=95&sign=9f77910883c7e8175bc3c23ce822ac9d&c_uniq_tag=o5u-iDZM19EiNG-360UND4nyJ82ft-fikYKKV8lkiMY&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=807x807&quality=95&sign=f43708dca733ce279d689363767d280a&c_uniq_tag=T-Sj0-lBWppiYHOhoGvNWoDnC4Y5X1xnmrG26dIZM3U&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=1280x1280&quality=95&sign=3cc8f29161a6ba0201ef9e592fe71be7&c_uniq_tag=glmlkZnwLrA3TaldfiNcn6dee5Sf2IefwNm3xbmh9pI&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=1500x1500&quality=95&sign=73723f2d706e9664663f39ffc245d422&c_uniq_tag=obvOSAyEyU7ytJJ55GDakDtijFs1VzmRdVAHVcX-ya4&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=130x130&quality=95&sign=79497116fc76c449e6ebedb32f206c69&c_uniq_tag=2xuzJzQCcYpQCTgNiCQjKNfRmnmkdbnns0Jn6Hn2b34&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=200x200&quality=95&sign=c3420abcf5bff823cbf18a958b1e4843&c_uniq_tag=J48Fc7GFLMKH0cB1Y3EeCrnvkEkZupHjftb_IgZHpvo&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=320x320&quality=95&sign=efbf91dfc86adadedd5fe9f7d0d6182a&c_uniq_tag=TzeTXRsTNZ0q69WZxRnMfczFWXl6-HOz696BHpU3xs8&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/luV40lVnIq2nyJPhn68ZTF24PspUPlANBBln1A/6xBCrwvCh9U.jpg?size=510x510&quality=95&sign=06a9ea13138ccfa81686d277fbf561d8&c_uniq_tag=bABL0HTDV6oL0gXLVW9fmsxNd_vYsv4Zxr01U6oEgwk&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '5821318ca523ba191b',
#                                                     'album_id': -7,
#                                                     'date': 1653638060,
#                                                     'id': 457331779,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=75x75&quality=95&sign=63900358215fa9c8fa6e474144cb9d4d&c_uniq_tag=g2BaRXPMdsGPPnkbuMC3OXFmUx6KkHcfeC-qm89c5z0&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=130x130&quality=95&sign=10b79cc628fc4c8a582d185c14b5d0a5&c_uniq_tag=EWCAdeb1SqV9UVsG6ygME8tfcYtV8L7JHlDeu5mEmn0&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=604x604&quality=95&sign=4afcb1021c1fc630d5acfaccf6815e6b&c_uniq_tag=cschZJjFAgBcgif2qLTnM_lDZYu8QhGOOGIk6axZIx8&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=807x807&quality=95&sign=43e05441dc14aaaa0c87720c63adbb61&c_uniq_tag=ZkenMzmY-Roo4x5rcfng2hsqdzJ-uG8BtdlB27sS_ps&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=1280x1280&quality=95&sign=8f480fa85cb81be882877d6a97240245&c_uniq_tag=NxoEDgJMzOwX7MQAfynCTvOOon1UXXm7GQFY7jfHzxo&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=1500x1500&quality=95&sign=1e3dd327784e4c403929f276d4788983&c_uniq_tag=6BcqZtInmkWAjX1GRNyf-fYAKETFE9C13ptJLw-tAIo&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=130x130&quality=95&sign=10b79cc628fc4c8a582d185c14b5d0a5&c_uniq_tag=EWCAdeb1SqV9UVsG6ygME8tfcYtV8L7JHlDeu5mEmn0&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=200x200&quality=95&sign=3551cc8342fc84739e2592b548321b88&c_uniq_tag=A6fFIq3FaEJocwMC28sIB4fBAtFgdF-1arMfoqqDXnY&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=320x320&quality=95&sign=71b5130327e2b834170eeb396783de06&c_uniq_tag=n3-faeCatw5QfRgTWf_4manaH7OiCCW-CefH2_Kll5U&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/kZNrcS8SA4l2_dQ6g9fxn8rHKDiuhGysHDfGFg/0BxmVvcNprg.jpg?size=510x510&quality=95&sign=5f09def0541fc5a8e1ef676b19e872aa&c_uniq_tag=YCxNEWk3hpP5wJkasWHuDhxzVBMfrkD6zbnSG9eWqOY&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '52059d50eda07ed144',
#                                                     'album_id': -7,
#                                                     'date': 1653638060,
#                                                     'id': 457331781,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=75x75&quality=95&sign=f675def36d93d0d4d490d1b72709c7c2&c_uniq_tag=YRhcTt-ryJfaZTSmRYTkWt86OzFlnPCzmIna77hhqLk&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=130x130&quality=95&sign=f236de80d90b9f2901cf714d4ae28bee&c_uniq_tag=aehHh4y0UCICIfo3dWs_XvMSkPOFlMwJRuYP-NKQ0j0&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=604x604&quality=95&sign=e5086569ea176dd82d45d730689df88d&c_uniq_tag=84Y96oiIj3g7gLDpmeCHc5ETOWgjBzb5qrtTnzouC1A&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=807x807&quality=95&sign=f7e2a4cf70821ff1627d92772f518d92&c_uniq_tag=1XizblR_6-FK8pwLerZ7VbwAyNmp3pjINffkbQE5prs&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=1280x1280&quality=95&sign=8222c1b26ccc688220a986442ba82659&c_uniq_tag=iO0EBvPZS_RgLThqaFD4kKxAO6aAXHzTjqJF10l-izo&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=1500x1500&quality=95&sign=b31b29c78d5176e949754ba850e5d5f3&c_uniq_tag=2YeEjxzBOMo_xWCHKN_5ZoJKSNupWR2xL0oHDyBWB1s&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=130x130&quality=95&sign=f236de80d90b9f2901cf714d4ae28bee&c_uniq_tag=aehHh4y0UCICIfo3dWs_XvMSkPOFlMwJRuYP-NKQ0j0&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=200x200&quality=95&sign=f0d40b99af2992551efb06dee59a6906&c_uniq_tag=ixZkYcipL7mDe95QcslDtLMLjGMqhBAB5E963gUESc0&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=320x320&quality=95&sign=81b32245931dd40bab307a8666fa8b7d&c_uniq_tag=0tiBVv08zLpN5ypPpgHBXqPt2iASQRb7Fl80NVl3zI4&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/Su3EzLtHBOFH7dcRzaIDgJN4Xuz7j_ikYuJjtQ/vPlIUPZpeiI.jpg?size=510x510&quality=95&sign=321510dea87592f5bbc92817db47bbd9&c_uniq_tag=yPFeFhwdL_WczSjd-vc3-D2Q0AZ-EYPuFpcsI88pEGE&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '53af2c5c3b3332f3b8',
#                                                     'album_id': -7,
#                                                     'date': 1653638060,
#                                                     'id': 457331782,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=75x75&quality=95&sign=c5fbb06d8183982386156702fd0c2b91&c_uniq_tag=T90dRShQ_C0dENODcpCOJVvYO1Kw9-YDccMKRcgWXtw&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=130x130&quality=95&sign=ca271d970a8db82208503f52e0930d0c&c_uniq_tag=RVirhIzo7aBD4lqlrmkqrs8VDKXkiGXUg0xG-OboJ6s&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=604x604&quality=95&sign=fe18f86f7430b6e4c634ec20ff1f0369&c_uniq_tag=IEmNWAKVe3Rxc8bu2NmuQH15Kb4QER1Nwrghqs0y_E0&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=807x807&quality=95&sign=230d3b8ecf9f621330c13ad75a577481&c_uniq_tag=j7ZWt-QbHNW9PSmuzy2aTjP991p_7w6RilnccQEUUOM&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=1280x1280&quality=95&sign=88c54820fe2c493756ce77a301c1fbea&c_uniq_tag=_1-BfzsJsb105UHRt4ffDRZH2tU-_3a4tN8WQ5uqO88&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=1500x1500&quality=95&sign=93d7a058963ce12cca68afb03389d9b5&c_uniq_tag=mvaXQxFlwvPxdiJmt9wEzVOqwLPd08uwOZ0XyPG5i48&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=130x130&quality=95&sign=ca271d970a8db82208503f52e0930d0c&c_uniq_tag=RVirhIzo7aBD4lqlrmkqrs8VDKXkiGXUg0xG-OboJ6s&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=200x200&quality=95&sign=0c356c6ffd7516c3ac3d921e829fbf0f&c_uniq_tag=XNqpbUu3ZouhQOTuPQppV3xdy_qbdaWxhmitH5FHiuk&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impg/V39eEn_YIYDCdBTD_AAeGnas8VnMzsYw6gGXWQ/d6_oQRqYpNc.jpg?size=320x320&quality=95&sign=bdca0a7ad52ef49cd8dbe962d696fc48&c_uniq_tag=kuEDp8xoGKU6iR5b10OEhWAYiagGUb1vJDwM97AfXWg&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
# ...
#                                                                'width': 130},
#                                                               {'height': 155,
#                                                                'type': 'p',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=200x155&quality=96&sign=681f2517ed68601f677cb527407da367&c_uniq_tag=DnKcFczWwdgVyPlOc9BYPNRQHm41IlFtOWEUuUZgs2M&type=album',
#                                                                'width': 200},
#                                                               {'height': 249,
#                                                                'type': 'q',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=320x248&quality=96&sign=89f7d853ea874659c52b1dcdbdfaf343&c_uniq_tag=IeZI48kIeBJO6ChwDonhUllHTJqdHLDtKIzX-VBia74&type=album',
#                                                                'width': 320},
#                                                               {'height': 396,
#                                                                'type': 'r',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=510x396&quality=96&sign=e16ed7473fed4b2a4dfe0a74b4d904b8&c_uniq_tag=UPmV6fYljdH7cyl5rYCclcMSRCyUD4zVS9XlT5IDY_o&type=album',
#                                                                'width': 510},
#                                                               {'height': 58,
#                                                                'type': 's',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=75x58&quality=96&sign=f7131be21285ee3aceae13316be743e5&c_uniq_tag=fBiQAvuxpauVWwEfEgF8nrlfYsuqZGROZTTwZH-BjxQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 1786,
#                                                                'type': 'w',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=2300x1786&quality=96&sign=26342360b23badfb7dc3df724de9c7e2&c_uniq_tag=jYYcfBThNhtNLN1ibbw0vUywv5T7wt26lcsVl_j78Pg&type=album',
#                                                                'width': 2300},
#                                                               {'height': 469,
#                                                                'type': 'x',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=604x469&quality=96&sign=9ad2d6c2dfb9975a24cd877d0445eb76&c_uniq_tag=CVYOxdLD9jRL9Z_q0Zkp2TyN3YHQ6SHt4wLQVAWOPfY&type=album',
#                                                                'width': 604},
#                                                               {'height': 627,
#                                                                'type': 'y',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=807x627&quality=96&sign=9912431efa673aa19481e51cf4cef368&c_uniq_tag=BcifcztACsGlGWaP_chDtEM3nrP5XK_74fgxTrYldWY&type=album',
#                                                                'width': 807},
#                                                               {'height': 994,
#                                                                'type': 'z',
#                                                                'url': 'https://sun2.norilsk.userapi.com/impf/8T2XLUjNPPsvPCbB2d-kU5VX9M3A4t2mtc0yzQ/NNcXkzvdtrE.jpg?size=1280x994&quality=96&sign=0bf69f1db6cd2db7fdacd8bcaa9474bd&c_uniq_tag=6theJghLcjRrYaQmUaJDxTBerI3I-rZErSe1WfhVA3w&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1595,
#                                       'groups_can_post': True},
#                          'date': 1589791755,
#                          'from_id': -22822305,
#                          'hash': 'UZW8VTRnPDw2ZifGtQ',
#                          'id': 1093264,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 10229,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 5259, 'user_reposted': 0},
#                          'text': 'Групповые видеозвонки ворвались в нашу '
#                                  'жизнь. Сейчас это единственный способ '
#                                  'встретиться с друзьями, коллегами или '
#                                  'наставниками: отметить день рождения, '
#                                  'поиграть в «Мафию», позаниматься с тренером. '
#                                  'Теперь всё это можно сделать прямо '
#                                  'ВКонтакте!\n'
#                                  '\n'
#                                  'Открывайте подходящую беседу в мобильном '
#                                  'приложении VK, нажимайте на иконку трубки и '
#                                  'выбирайте, с кем из чата хотите созвониться. '
#                                  'Вы сможете добавить собеседника и во время '
#                                  'разговора. Одновременно общаться сейчас '
#                                  'могут 8 человек.\n'
#                                  '\n'
#                                  'Чтобы получить доступ к новой функции, '
#                                  'обновите мобильное приложение. Вы сразу же '
#                                  'сможете принимать групповые видеозвонки, а '
#                                  'возможность создавать их появится у всех в '
#                                  'ближайшие дни. \n'
#                                  '\n'
#                                  'Мы будем оперативно добавлять новые функции, '
#                                  'чтобы вы были ближе к тем, кто важен и '
#                                  'дорог. Расстояния не преграда — с групповыми '
#                                  'видеозвонками ВКонтакте!',
#                          'views': {'count': 1620381}},
#                         {'attachments': [{'photo': {'access_key': 'c075045954054dea5d',
#                                                     'album_id': -7,
#                                                     'date': 1589721561,
#                                                     'id': 457310823,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1093009,
#                                                     'sizes': [{'height': 73,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=130x73&quality=96&sign=a8ac778967809c89ad78901474b2f594&c_uniq_tag=OXw7UP1eu_M5ZDgKhwDz4B6njBRTQPIirWiDAXOMPGw&type=album',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=130x87&quality=96&crop=119,0,1261,844&sign=164b272dd7b9ae146419b396cde1778e&c_uniq_tag=jdgRyh1lRjsIZ5L0N0Ep6sP7o_kG4zLfi8Z98wtGvuE&type=album',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=200x133&quality=96&crop=115,0,1269,844&sign=a148b2e1757beb5d311db4fca11c06e6&c_uniq_tag=jQy8D-ewd3GMSFL9kuAZeaSANJhIoJy9qaz19aJ172Y&type=album',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=320x213&quality=96&crop=116,0,1268,844&sign=e4450490fd7348e072f3d3b4fa096752&c_uniq_tag=YmHB_B4D-KFjeQRSDf81hngz7f_iywVcFaphIo7eKIk&type=album',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=510x340&quality=96&crop=117,0,1266,844&sign=e76de71a3aa94bb9a2d8046e8db47ec3&c_uniq_tag=AEaiWsP6-KvPgOwVa6VsB6qh37lcaxz9Uca7VKx8ArE&type=album',
#                                                                'width': 510},
#                                                               {'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=75x42&quality=96&sign=6e58bd42d4a3476c44cb60f74ad2285a&c_uniq_tag=o00UFG-6ASEkvZ6yB6fhc6Lz7v9Y1P0nZ8Te1Zt8-Cw&type=album',
#                                                                'width': 75},
#                                                               {'height': 844,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=1500x844&quality=96&sign=31e562120cacc75ae31908978fc6cab3&c_uniq_tag=3rTnSqqJnyyveQBTDQdxeXnMEB_-_cXbgr9z2H0vQ54&type=album',
#                                                                'width': 1500},
#                                                               {'height': 340,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=604x340&quality=96&sign=c862b6a54c061a342a86ce9e623bdfa5&c_uniq_tag=U-E_zai88Cx0Ftw3uh1Q31TQhhuLEzI02px_gassZY4&type=album',
#                                                                'width': 604},
#                                                               {'height': 454,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=807x454&quality=96&sign=89ec5e391828b029b3f715b0622df805&c_uniq_tag=0a79ohgThgimW_m0kvctlUixXjveFwCa4rVe_HBJKc8&type=album',
#                                                                'width': 807},
#                                                               {'height': 720,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1.norilsk.userapi.com/impg/brzvhVabxi7IIhZREuXMn3ljFjJTptG9L62Y_g/y6_2Gh5GoFQ.jpg?size=1280x720&quality=96&sign=1b6307d6abc55fb6770464d6bdbcba35&c_uniq_tag=JlBNrneTitB3BQJ4MMuYQ5wtkcaTJoI4ujvYSQRoGc4&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 407,
#                                       'groups_can_post': True},
#                          'date': 1589721655,
#                          'from_id': -22822305,
#                          'hash': '7lXz1V6pT4ZVMuOpHQ',
#                          'id': 1093009,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 2396,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 199, 'user_reposted': 0},
#                          'text': '[club86529522|VK Fest] шагает по планете уже '
#                                  'третий день и несёт добро каждому! '
#                                  'Выступления более 70 артистов, интервью со '
#                                  'звёздами — и по 30 миллионов просмотров '
#                                  'ежедневно! Но мы не просто развлекаемся, а '
#                                  'ещё и помогаем людям — собираем средства для '
#                                  'трёх некоммерческих организаций, которые '
#                                  'сосредоточились на борьбе с пандемией и её '
#                                  'последствиями.\n'
#                                  '\n'
#                                  'Чтобы принять участие в благотворительной '
#                                  'акции, отправьте друзьям подарок с хомяком '
#                                  'Сеней. Он стоит 15 голосов. К собранным '
#                                  'средствам мы добавим своё пожертвование и '
#                                  'всю сумму перечислим:\n'
#                                  '\n'
#                                  '• фондам [club36242746|«Не напрасно»] и '
#                                  '[club18750533|AdVita], которые сейчас '
#                                  'поддерживают больницы и медперсонал в борьбе '
#                                  'с коронавирусной инфекцией;\n'
#                                  '\n'
#                                  '• центру [club122762463|«Насилию.нет»], '
#                                  'команда которого помогает людям в трудной '
#                                  'жизненной ситуации и создаёт '
#                                  'просветительские проекты, особенно '
#                                  'актуальные во время самоизоляции.\n'
#                                  '\n'
#                                  'Дарите Сеню и смотрите VK Fest! Сборы '
#                                  'продолжатся до конца фестиваля.',
#                          'views': {'count': 608749}}]}}

# %% [markdown]
# Анализируя ответ, понимаем, что по ключу `count` можно найти общее количество сообщений в новостной ленте, а по ключу `items` — сами сообщения.
#
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 1307907,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1657189899,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'Наверняка вам хоть раз писали неизвестные люди. Теперь приложение ВКонтакте будет предупреждать, если к собеседнику стоит отнестись с осторожностью. \n\nВ новом групповом чате или беседе с незнакомым человеком наша система определит возможного спамера и покажет специальное уведомление прямо в переписке. Из него вы сможете отправить жалобу и добавить пользователя в чёрный список. Диалог или чат в этом случае будут удалены. Так и другие участники не перейдут по опасным ссылкам.',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1657189899,
#     'id': 457332523,
#     'owner_id': -22822305,
#     'access_key': '720e171a5115a08c28',
#     'post_id': 1307907,
#     'sizes': [{'height': 70,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=75x70&quality=95&sign=16604c19eba46c485b88db602edf0d16&c_uniq_tag=9arKyoONH6coX0vzesNyYjrcrEiyKJxhYxsqRQqDnsE&type=album',
#       'type': 's',
#       'width': 75},
#      {'height': 122,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=130x122&quality=95&sign=24edd945412f0ba74d22f78bd921cafb&c_uniq_tag=CBCb4M-0Z0Zd87PubtZVfNcxTpoep7trbFCFwaJtTkU&type=album',
#       'type': 'm',
#       'width': 130},
#      {'height': 566,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=604x566&quality=95&sign=e75e8ea0188ffebe303863cb8ca725be&c_uniq_tag=iBIxBmouJBnwbQb791lVdWapYEbrb7vMwG1MGewMHuE&type=album',
#       'type': 'x',
#       'width': 604},
#      {'height': 757,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=807x757&quality=95&sign=5f2095b713bd52a983c90cb82b4f3e65&c_uniq_tag=DHU_-GPiJ8-SN-F-1bgpL89t_TyO-yezSogn-wHXxHo&type=album',
#       'type': 'y',
#       'width': 807},
#      {'height': 1200,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=1280x1200&quality=95&sign=aafd61122ec205ddef7923ec990d1105&c_uniq_tag=TRivw_rhiRzsl9kY5bvrQ2HKbpStYxZyRbzBTt-IRfU&type=album',
#       'type': 'z',
#       'width': 1280},
#      {'height': 2157,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=2300x2157&quality=95&sign=51cbfd2e2a00bbf48aa15250c19d6407&c_uniq_tag=cV4EAI-zDGyqTqoNrgWsOKaXpFAuarPROwDiteZ9-hg&type=album',
#       'type': 'w',
#       'width': 2300},
#      {'height': 122,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=130x122&quality=95&sign=24edd945412f0ba74d22f78bd921cafb&c_uniq_tag=CBCb4M-0Z0Zd87PubtZVfNcxTpoep7trbFCFwaJtTkU&type=album',
#       'type': 'o',
#       'width': 130},
#      {'height': 188,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=200x188&quality=95&sign=110b9cab5508bd78e553b7c7268965d3&c_uniq_tag=Q-TDYnegB0m5RlaU4OjwKHpVhzOz4__3vafu1sPWwp8&type=album',
#       'type': 'p',
#       'width': 200},
#      {'height': 300,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=320x300&quality=95&sign=da496ba9298bf71306da4f0328e34928&c_uniq_tag=3TSdyVY3DjtkFJuNG_PL8HjwIAiOwsLV9jSTNrBvud0&type=album',
#       'type': 'q',
#       'width': 320},
#      {'height': 478,
#       'url': 'https://sun1.norilsk.userapi.com/impg/_K9M_CnDfk6pu4Jw7fguQdz2qR-t1pmwm9B4fQ/xJjM39a7qUA.jpg?size=510x478&quality=95&sign=dc633b02b188d87f86ead99e2aa7527d&c_uniq_tag=T3w2q0CCMIAnxgr5CLb86BP-FvdRcZ00ZIg9ktsIplc&type=album',
#       'type': 'r',
#       'width': 510}],
#     'text': '',
#     'user_id': 100}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 488, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 1875, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 629, 'user_reposted': 0},
#  'views': {'count': 699513},
#  'hash': 'Ye-Zxv4tJtTueWYWtw'}

# %% [markdown]
# В полях `comments`, `likes` и `reposts` содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.
#
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь `stats`. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'VK Клипы — это место встречи т': [168, 956, 394, 1655742420],
#  '[club86529522|VK Fest] расширя': [312, 1626, 845, 1653545902],
#  'За первый квартал 2022 года ав': [301, 1459, 488, 1652363220],
#  'Наверняка вам хоть раз писали ': [488, 1875, 629, 1657189899],
#  'Помните, когда-то в сообщениях': [331, 1314, 497, 1656572580],
#  'Представляем VK Мессенджер: он': [600, 1983, 1266, 1652775512],
#  'Собрали в обзоре главные июньс': [361, 777, 344, 1656684843],
#  'Теперь зрителям VK Видео будет': [537, 1654, 857, 1655821398],
#  'Что внутри у VK Видео? Рассказ': [111, 607, 232, 1657185907],
#  'Что нового ВКонтакте по итогам': [428, 1496, 673, 1654181416]}

# %% [markdown]
# Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём `API`: всё, что можно делать вручную через браузер, доступно и в `API`.
# ### ДОПОЛНИТЕЛЬНО
#
# Если вы размещаете рекламу во ВКонтакте, то можно выгружать всю статистику через [ads API](https://vk.com/dev/ads).
#
# Полный список методов ВКонтакте можно посмотреть в [документации](https://vk.com/dev/methods).

# %% [markdown]
# ### ДРУГИЕ API <a class="anchor" id=6-5></a>
#
# Вы познакомились с интерфейсами прикладного программирования — API (на примере API социальной сети ВКонтакте).
#
# API для разработчиков предоставляют и многие другие платформы. Вот список, пожалуй, самых популярных из них:
#
# [Google Maps API](https://developers.google.com/maps/)
#
# [YouTube API](https://developers.google.com/youtube/)
#
# [Twitter API](https://dev.twitter.com/overview/documentation)
#
# [Facebook API](https://developers.facebook.com/docs/)
#
# Информацию о сторонних API можно найти в [каталоге Web API](https://www.programmableweb.com/category/all/apis). Также можно воспользоваться интернет-поиском, указав в строке поиска, например, «курсы валют API» или «прогноз погоды api», — среди первых результатов выдачи чаще всего с лёгкостью можно найти ссылки на необходимый функционал.

# %% [markdown]
# ## 7. Регулярная выгрузка данных <a class="anchor" id=7></a>
#
# [к содержанию](#0)
#
# Скрипт можно использовать разными способами:
#
# - Если вам нужно выполнить код один раз или выполнять его очень редко (от случая к случаю), вы можете запустить скрипт вручную из командной строки.
#
# - Если вы, например, написали на Python серверную часть веб-сайта и хотите, чтобы ваш код мог в любое время обрабатывать запросы, вы захотите запустить его как фоновый процесс.
#
# А что делать, если вам нужно, чтобы ваш скрипт запускался иногда? Каждую пятницу, 13-го? В день рождения супруга (или супруги)? Или просто каждый час?
#
# В этом случае вам нужен автоматический запуск скриптов, или, как часто его называют программисты, запуск по крону — от английского акронима **Cron** (англ. Command Run ON) — названия системы для автоматического запуска программ и скриптов на сервере в определённое время.
#
# Автоматический запуск может понадобиться, например:
#
# - если вы хотите с определённой периодичностью скачивать новую информацию с сайтов, например выполнять парсинг новостей для последующего анализа (как мы уже знаем, этот процесс называется web-scraping);
# - если ваш скрипт должен следить за курсом акций и каждую минуту делать запрос по API, чтобы получить новые котировки;
# - если вы написали обучающую платформу и вам нужно каждый час проверять, кто из студентов приступил к занятиям и насколько успешно продвигается их обучение;
# - если у вас есть 500 вендинговых автоматов по продаже солнечных очков и каждые пять минут вы должны опрашивать все автоматы, чтобы узнать, не закончились ли очки.
#
# ### КАК НАСТРОИТЬ АВТОМАТИЧЕСКИЙ ЗАПУСК
#
# Во всех операционных системах есть встроенные средства запуска программ по расписанию. Однако можно задать расписание запуска необходимых вам функций на языке Python внутри скрипта.
#
# Исполняемый по расписанию код часто называют задачей (англ. `task`). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль `schedule` (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль `schedule` не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %% [markdown]
# ### ПОСТАНОВКА ЗАДАЧИ
#
# Рассмотрим вариант автоматического запуска простой функции, которая выводит на экран короткое сообщение:

# %%
def task(): 
    print('Hello! I am a task!') 
    return

# %% [markdown]
# Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
#
# Для запуска задачи через определённые интервалы времени в модуле `schedule` используется метод `every()`, который получает в качестве единственного аргумента число, указывающее, как часто следует запускать код.
#
# Далее вызывается метод, определяющий единицы измерения промежутков времени, через которые будет выполняться функция. В нашем примере это минуты. Вот как будет выглядеть итоговый код:

# %%
schedule.every(15).minutes.do(task)
# Out:
# Every 15 minutes do task() (last run: [never], next run: 2022-07-15 15:14:49)

# %% [markdown]
# ### ВЫПОЛНЕНИЕ ФУНКЦИИ
#
# После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (`schedule`). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод `run_pending()` для объекта `schedule`, который будет **проверять, нет ли задачи**, которую пора выполнить.
#
# После вызова метода `run_pending()` нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.
#
# Для создания паузы мы будем использовать метод `sleep` из модуля `time`, поэтому наш код начнётся с импорта данного модуля:

# %%
import schedule

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(1).minutes.do(task)

import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Hello! I am a task!
# Hello! I am a task!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13179/3059109739.py in <module>
#      10 while True:
#      11     schedule.run_pending()
# ---> 12     time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 8. Итоги <a class="anchor" id=8></a>
#
# [к содержанию](#0)
#
# ### ПАРСИНГ САЙТОВ
#
# [Официальная документация BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# ### РАБОТА С API
#
# [Описание методов API ВКонтакте](https://vk.com/dev/methods)
#
# ### АВТОМАТИЧЕСКИЙ ЗАПУСК СКРИПТОВ
#
# [Документация модуля schedule](http://schedule.readthedocs.io/)
#
# [Как работать с планировщиком заданий в ОС Windows](https://www.comss.ru/page.php?id=4840)
#
# [О том, что такое CRON и как его использовать](https://tproger.ru/translations/guide-to-cron-jobs/)

# %% [markdown]
# ## 9. Подготовка к аттестации по Python <a class="anchor" id=9></a>
#
# [к содержанию](#0)
