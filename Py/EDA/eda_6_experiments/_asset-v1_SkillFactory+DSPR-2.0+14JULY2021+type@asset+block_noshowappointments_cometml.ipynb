# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Настройка CometML
# <img src='https://camo.githubusercontent.com/b35adf34bc440ea2ac19bb0d3432f48e26d71ab8e4c256e936b709eec44f5b19/68747470733a2f2f7777772e636f6d65742e6d6c2f696d616765732f6c6f676f5f636f6d65745f6c696768742e706e67' width=500px>

# %%
#!pip install comet_ml

# %%
from comet_ml import Experiment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\config.py:57, in <module>
#      56 try:  # everett version 1.0.1 or greater
# ---> 57     from everett.ext.inifile import ConfigIniEnv
#      58 except ImportError:  # everett version 0.9 for Python 2
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\everett\ext\inifile.py:16, in <module>
#      14 import os
# ---> 16 from configobj import ConfigObj
#      18 from everett import NO_VALUE
#
# ModuleNotFoundError: No module named 'configobj'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Личные документы\Python\Py\eda_6_experiments\_asset-v1_SkillFactory+DSPR-2.0+14JULY2021+type@asset+block_noshowappointments_cometml.ipynb Ячейка 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/eda_6_experiments/_asset-v1_SkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40asset%2Bblock_noshowappointments_cometml.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from comet_ml import Experiment
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\__init__.py:25, in <module>
#      22 import traceback
#      24 from ._logging import _setup_comet_http_handler, _setup_comet_logging
# ---> 25 from ._online import ExistingExperiment, Experiment
#      26 from ._reporting import (
#      27     EXPERIMENT_CREATED,
#      28     EXPERIMENT_CREATION_DURATION,
#      29     EXPERIMENT_CREATION_FAILED,
#      30 )
#      31 from ._typing import Any, Dict, Optional, Tuple
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\_online.py:23, in <module>
#      19 import traceback
#      21 import sentry_sdk
# ---> 23 from ._error_tracking import _setup_sentry_error_tracker
#      24 from ._logging import _setup_comet_http_handler
#      25 from ._reporting import (
#      26     EXPERIMENT_CREATED,
#      27     EXPERIMENT_CREATION_DURATION,
#      28     EXPERIMENT_CREATION_FAILED,
#      29 )
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\_error_tracking.py:21, in <module>
#      19 from ._logging import _setup_sentry_error_handlers
#      20 from ._typing import Any, Dict, Optional
# ---> 21 from .env_logging import _get_non_pii_env_details
#      24 def _setup_sentry_error_tracker(
#      25     sentry_dsn, experiment_id, comet_url, debug, feature_toggles
#      26 ):
#      27     # type: (str, str, str, bool, Optional[Dict[str, bool]]) -> Any
#      28     sentry_client = sentry_sdk.init(
#      29         sentry_dsn,
#      30         integrations=[],
#      31         default_integrations=False,
#      32         debug=debug,
#      33     )
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\env_logging.py:38, in <module>
#      35 from six.moves.urllib.parse import urlparse
#      37 from ._typing import Any, Dict, List, Optional, Tuple
# ---> 38 from .connection import get_backend_address
#      39 from .logging_messages import (
#      40     LOG_CONDA_ENV_ERROR,
#      41     LOG_CONDA_ENV_RETURN_CODE,
#    (...)
#      45     LOG_CONDA_PACKAGES_RETURN_CODE,
#      46 )
#      47 from .messages import SystemDetailsMessage
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\connection.py:34, in <module>
#      31 import zipfile
#      33 import comet_ml
# ---> 34 from comet_ml import config
#      35 from comet_ml._reporting import WS_ON_CLOSE, WS_ON_ERROR, WS_ON_OPEN
#      36 from comet_ml.config import (
#      37     DEFAULT_ASSET_UPLOAD_SIZE_LIMIT,
#      38     DEFAULT_UPLOAD_SIZE_LIMIT,
#      39     Config,
#      40     get_config,
#      41 )
#
# File c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\config.py:59, in <module>
#      57     from everett.ext.inifile import ConfigIniEnv
#      58 except ImportError:  # everett version 0.9 for Python 2
# ---> 59     from everett.manager import ConfigIniEnv as UpstreamConfigIniEnv
#      61     class ConfigIniEnv(UpstreamConfigIniEnv):
#      62         """Backport of everett ConfigIniEnv in Python 3 that save the path when found"""
#
# ImportError: cannot import name 'ConfigIniEnv' from 'everett.manager' (c:\Users\AubakirovMA\Anaconda3\lib\site-packages\everett\manager.py)

# %%
import comet_ml
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\config.py", line 57, in <module>
#     from everett.ext.inifile import ConfigIniEnv
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\everett\ext\inifile.py", line 16, in <module>
#     from configobj import ConfigObj
# ModuleNotFoundError: No module named 'configobj'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\AubakirovMA\AppData\Local\Temp\ipykernel_1444\3498229024.py", line 1, in <cell line: 1>
#     import comet_ml
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\__init__.py", line 25, in <module>
#     from ._online import ExistingExperiment, Experiment
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\_online.py", line 23, in <module>
#     from ._error_tracking import _setup_sentry_error_tracker
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\_error_tracking.py", line 21, in <module>
#     from .env_logging import _get_non_pii_env_details
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\env_logging.py", line 38, in <module>
#     from .connection import get_backend_address
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\connection.py", line 34, in <module>
#     from comet_ml import config
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\comet_ml\config.py", line 59, in <module>
#     from everett.manager import ConfigIniEnv as UpstreamConfigIniEnv
# ImportError: cannot import name 'ConfigIniEnv' from 'everett.manager' (c:\Users\AubakirovMA\Anaconda3\lib\site-packages\everett\manager.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "c:\Users\AubakirovMA\Anaconda3\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# Создайте эксперимент с помощью вашего API ключа
experiment = Experiment(
    api_key="gUJB4A5Xyni7vEzn5F7be7scu",
    project_name="midecal-appointment",
    workspace="hoittoken",)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Личные документы\Python\Py\eda_6_experiments\_asset-v1_SkillFactory+DSPR-2.0+14JULY2021+type@asset+block_noshowappointments_cometml.ipynb Ячейка 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/eda_6_experiments/_asset-v1_SkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40asset%2Bblock_noshowappointments_cometml.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Создайте эксперимент с помощью вашего API ключа
# ----> <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/eda_6_experiments/_asset-v1_SkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40asset%2Bblock_noshowappointments_cometml.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> experiment = Experiment(
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/eda_6_experiments/_asset-v1_SkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40asset%2Bblock_noshowappointments_cometml.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     api_key="gUJB4A5Xyni7vEzn5F7be7scu",
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/eda_6_experiments/_asset-v1_SkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40asset%2Bblock_noshowappointments_cometml.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     project_name="midecal-appointment",
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/eda_6_experiments/_asset-v1_SkillFactory%2BDSPR-2.0%2B14JULY2021%2Btype%40asset%2Bblock_noshowappointments_cometml.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     workspace="hoittoken",)
#
# NameError: name 'Experiment' is not defined

# %% [markdown]
# # Загрузка данных

# %%
df = pd.read_csv('./KaggleV2-May-2016.csv')

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender  ... Handcap SMS_received  No-show
# 0  2.987250e+13        5642903      F  ...       0            0       No
# 1  5.589978e+14        5642503      M  ...       0            0       No
# 2  4.262962e+12        5642549      F  ...       0            0       No
# 3  8.679512e+11        5642828      F  ...       0            0       No
# 4  8.841186e+12        5642494      F  ...       0            0       No
#
# [5 rows x 14 columns]

# %% [markdown]
# # Визуализация

# %% [markdown]
# ### Распределение числовых признаков

# %%
df.hist(figsize=(16,14));
#логируем гистограмму
experiment.log_figure(figure=plt)
# Out:
# {'api': 'https://www.comet.ml/api/rest/v1/image/get-image?imageId=f1d26e00afca487a8511d934ff5308ff&experimentKey=d41b0cbd2fec4239925ec5edf3d4c04b',
#  'imageId': 'f1d26e00afca487a8511d934ff5308ff',
#  'web': 'https://www.comet.ml/api/image/download?imageId=f1d26e00afca487a8511d934ff5308ff&experimentKey=d41b0cbd2fec4239925ec5edf3d4c04b'}

# %% [markdown]
# *Проанализируем число людей каждого возраста*

# %%
print("Уникальные значения в `Age` => {}".format(df.Age.unique()))
# Out:
# Уникальные значения в `Age` => [ 62  56   8  76  23  39  21  19  30  29  22  28  54  15  50  40  46   4
#   13  65  45  51  32  12  61  38  79  18  63  64  85  59  55  71  49  78
#   31  58  27   6   2  11   7   0   3   1  69  68  60  67  36  10  35  20
#   26  34  33  16  42   5  47  17  41  44  37  24  66  77  81  70  53  75
#   73  52  74  43  89  57  14   9  48  83  72  25  80  87  88  84  82  90
#   94  86  91  98  92  96  93  95  97 102 115 100  99  -1]

# %%
# Удалим аномальные значения
df = df[(df.Age >= 0) & (df.Age <= 110)]
df.Age.value_counts()
# Out:
# 0      3539
# 1      2273
# 52     1746
# 49     1652
# 53     1651
#        ...
# 97       11
# 98        6
# 100       4
# 102       2
# 99        1
# Name: Age, Length: 102, dtype: int64

# %%
plt.figure(figsize=(24,6))
plt.xticks(rotation=90)
ax = sns.countplot(x=df.Age)
ax.set_title("Распределение пациентов по возрасту")
experiment.log_figure(figure=plt)
plt.show()

# %% [markdown]
# # Придет ли пациент на назначенный приием?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110521 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110521 non-null  float64
#  1   AppointmentID   110521 non-null  int64
#  2   Gender          110521 non-null  object
#  3   ScheduledDay    110521 non-null  object
#  4   AppointmentDay  110521 non-null  object
#  5   Age             110521 non-null  int64
#  6   Neighbourhood   110521 non-null  object
#  7   Scholarship     110521 non-null  int64
#  8   Hipertension    110521 non-null  int64
#  9   Diabetes        110521 non-null  int64
#  10  Alcoholism      110521 non-null  int64
#  11  Handcap         110521 non-null  int64
#  12  SMS_received    110521 non-null  int64
#  13  No-show         110521 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 17.6+ MB

# %% [markdown]
# ## Кодировка категориальных признаков

# %%
categorical_columns_names = ['Gender', 'Neighbourhood']

# %%
encoded_columns = pd.get_dummies(df, columns = categorical_columns_names)

# %%
encoded_columns.drop(['AppointmentID', 'PatientId', 'ScheduledDay', 'AppointmentDay', 'No-show'], axis=1, inplace = True)

# %%
encoded_columns.head()
# Out:
#    Age  Scholarship  ...  Neighbourhood_UNIVERSITÁRIO  Neighbourhood_VILA RUBIM
# 0   62            0  ...                            0                         0
# 1   56            0  ...                            0                         0
# 2   62            0  ...                            0                         0
# 3    8            0  ...                            0                         0
# 4   56            0  ...                            0                         0
#
# [5 rows x 90 columns]

# %%
y = df['No-show']

# %%
y
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 110522    No
# 110523    No
# 110524    No
# 110525    No
# 110526    No
# Name: No-show, Length: 110521, dtype: object

# %%
y = y.replace({'No': 0, 'Yes': 1})

# %%
y.value_counts(True)
# Out:
# 0    0.798084
# 1    0.201916
# Name: No-show, dtype: float64

# %% [markdown]
# ## Шкалирование данных

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(encoded_columns)

# %%
print(X.shape)
# Out:
# (110521, 90)

# %% [markdown]
# # Модель (этот раздел будет подробно изучен далее в курсе)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Инициализация модели

# %%
logreg = LogisticRegression()

# %%
random_state = 42

# %% [markdown]
# ### Обучение модели

# %%
logreg.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %% [markdown]
# #### Логирование параметров обучения

# %%
params={"random_state":random_state,
        "model_type":"logreg"
}

# %%
experiment.log_parameters(params)

# %% [markdown]
# ### Предсказания модели

# %%
y_pred = logreg.predict(X)

# %% [markdown]
# ### Анализ модели

# %%
accuracy = accuracy_score(y, y_pred)

print("Доля правильных ответов: {:6.3f}".format(accuracy))
# Out:
# Доля правильных ответов:  0.798

# %% [markdown]
# # Логирование метрик

# %%
metrics = {"accuracy":accuracy}

# %%
experiment.log_metrics(metrics)

# %% [markdown]
# <img src = 'https://miro.medium.com/max/1400/0*r2yYhe2DpE4d3WKP.png' width=700px>

# %%
experiment.log_confusion_matrix(y.tolist(), y_pred.tolist())
# Out:
# {'api': 'https://www.comet.ml/api/rest/v2/experiment/asset/get-asset?assetId=7455a9e4e8d8485487d9054b3ee4385b&experimentKey=d41b0cbd2fec4239925ec5edf3d4c04b',
#  'assetId': '7455a9e4e8d8485487d9054b3ee4385b',
#  'web': 'https://www.comet.ml/api/asset/download?assetId=7455a9e4e8d8485487d9054b3ee4385b&experimentKey=d41b0cbd2fec4239925ec5edf3d4c04b'}

# %%
experiment.display()
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://www.comet.ml/ketrint/medical-appointment/d41b0cbd2fec4239925ec5edf3d4c04b"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/ketrint/medical-appointment/d41b0cbd2fec4239925ec5edf3d4c04b
# COMET INFO:   Metrics:
# COMET INFO:     accuracy : 0.7980836221170637
# COMET INFO:   Others:
# COMET INFO:     notebook_url : https://colab.research.google.com/notebook#fileId=1KVu3r_Rqkz6x4mr7MZ2lArzJhTxp7ies
# COMET INFO:   Parameters:
# COMET INFO:     C                 : 1.0
# COMET INFO:     class_weight      : 1
# COMET INFO:     clip              : False
# COMET INFO:     copy              : True
# COMET INFO:     dual              : False
# COMET INFO:     feature_range     : (0, 1)
# COMET INFO:     fit_intercept     : True
# COMET INFO:     intercept_scaling : 1
# COMET INFO:     l1_ratio          : 1
# COMET INFO:     max_iter          : 100
# COMET INFO:     model_type        : logreg
# COMET INFO:     multi_class       : auto
# COMET INFO:     n_jobs            : 1
# COMET INFO:     penalty           : l2
# COMET INFO:     random_state      : 42
# COMET INFO:     solver            : lbfgs
# COMET INFO:     tol               : 0.0001
# COMET INFO:     verbose           : 0
# COMET INFO:     warm_start        : False
# COMET INFO:   Uploads:
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     figures             : 3
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 1 file(s), remaining 93.16 KB/493.08 KB

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# Визуализируйте корреляцию между числовыми признаками, использованными для обучения модели и залогируйте изображение в Comet.
#
# В качестве ответа приложите обновленный ноутбук.
#
# *Форма оценки ментором:*
#
# 1) Проведена визуализация корреляции между 7 числовыми признаками, использованными для обучения модели - 5 баллов
#
# 2) Произведено логирование графика в CometMl - 10 баллов
