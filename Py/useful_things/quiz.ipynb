# %%
lst = [1, 2, 3, 4, 5]
new_lst = [i * i for i in lst if i % 2 == 0]
print(new_lst)

# a) [1, 4, 9, 16, 25]
# b) [4, 16]
# c) [2, 4, 6, 8, 10]
# d) None of the above
# Out:
# [4, 16]

# %%
lst = [1, 2, 3, 4, 5]
for i in lst:
    if i ==3:
        break
    print(i)
else:
    print('End')    

# a) 1  2
# b) 1  2  End
# c) Error
# d) None of the above
# Out:
# 1
# 2

# %%
x = [1, 2, 3]
y = x
x.append(4)
print(y)

# a) [1, 2, 3]
# b) [1, 2, 3, 4]
# c) Error
# d) None of the above
# Out:
# [1, 2, 3, 4]

# %%
for i in range(3):
    for j in range(3):
        print(i * j)

# В ответах предствляем что
# каждый элемент выводится 
# с новой строки
# a) 0 0 0 1 2 3 0 2 4 
# b) 0 1 2 3 4 5 6 7 8
# c) 0 0 0 0 1 2 0 2 4
# d) None of the above
# Out:
# 0
# 0
# 0
# 0
# 1
# 2
# 0
# 2
# 4

# %% [markdown]
# ~~vbvb~~

# %%
def function(a, b):
    return a + b

print(function(2, 3, 4))

# a) 5
# b) 9
# c) Error
# d) None of the above
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Личные документы\Python\Py\useful_things\quiz.ipynb Cell 5 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/useful_things/quiz.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> def function(a, b):
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/useful_things/quiz.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     return a + b
# ----> <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/useful_things/quiz.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> print(function(2, 3, 4))
#
# TypeError: function() takes 2 positional arguments but 3 were given

# %%
def function(a, b=2, *arg, **kwarg):
    print(a, b, arg, kwarg)
    
function(1, 3, 4, 5, c=6, d=7)

# a) 1 3 (4, 5) {'c': 6, 'd': 7}
# b) 1 3 (4, 5) {'c': 6}
# c) 1 2 3 (3, 4, 5), {'c': 6, 'd': 7}
# d) None of the above
# Out:
# 1 3 (4, 5) {'c': 6, 'd': 7}

# %%
a = {1: 'one', 2: 'two', 3: 'three'}
for key in a:
    print(key, a[key])

# a) 1 one, 2 two, 3 three
# b) (1, 'one'), (2, 'two'), (3, 'three')
# c) {1: 'one', 2: 'two', 3: 'three'}
# d) Error
# Out:
# 1 one
# 2 two
# 3 three

# %%
a = 10
def func():
    global a
    a = 5
func()
print(a)

# a) 5
# b) 10
# c) Error
# d) None of the above
# Out:
# 5

# %% [markdown]
# ```python
#
# def productFib(prod):
#     f1 = 0
#     f2 = 1
#     while f1 * f2 <= prod:
#         f1, f2 = f2, f1 + f2
#         if f1 * f2 == prod:
#             return [f1, f2, True]
#     else:
#         return [f1, f2, False]
# print(productFib(1))
# print(productFib(4895))
# print(productFib(5895))
#
# ```

# %%
def productFib(prod):
    f1 = 0
    f2 = 1
    while f1 * f2 <= prod:
        f1, f2 = f2, f1 + f2
        if f1 * f2 == prod:
            return [f1, f2, True]
    else:
        return [f1, f2, False]
        
        
print(productFib(6))
print(productFib(4895))
print(productFib(5895))
# Out:
# [2, 3, True]
# [55, 89, True]
# [89, 144, False]

# %%
def productFib(prod: int):
    def lazy_fib():
            f1, f2 = 0, 1
            while True:
                yield [f1*f2, [f1,f2]]
                f1, f2 = f2, f1 + f2

    m, nums = next(filter(lambda x: x[0] >= prod, (x for x in lazy_fib())))

    return [*nums, m == prod]
    

print(productFib(4895))
print(productFib(5895))
# Out:
# [55, 89, True]
# [89, 144, False]

# %%
def lazy_fib():
    f1, f2 = 0, 1
    while True:
        yield [f1*f2, [f1,f2]]
        f1, f2 = f2, f1 + f2
        
lazy_fib()
# Out:
# <generator object lazy_fib at 0x000002050B178040>

# %%
def my_function():
    try:
        print('Hello')
        return
    finally:
        print('World')
        
my_function()
# Out:
# Hello
# World

# %% [markdown]
# ***

# %%
my_dict = {'a':1, 'b':2, 'c':3}
for key, value in my_dict.items():
    pass

(key, value) == [(key, value) for key, value
                    in {'a':1, 'b':2, 'c':3}.items()][-1]
# a) False
# b) True
# a) Error
# d) None of the above
# Out:
# True

# %%
def my_func(x):
    if x <= 0:
        return 0
    else:
        return x + my_func(x-1)
    
print(my_func(5))

# a) 5
# b) 9
# c) 15
# d) None of the above
# Out:
# 15

# %%
a = [1, 2, 3, 4, 5]
b = [i for i in a if i % 2 == 0]
print(b)

# a) [1, 2, 3, 4, 5]
# b) [2, 4]
# c) Error
# d) None of the above
# Out:
# [2, 4]

# %%
my_dict = {x: x**2 for x in [1, 2, 3, 4, 5]}
print(my_dict)

# a) {1: 1, 4: 2, 9: 3, 16: 4, 25: 5}
# b) {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# c) [1, 4, 9, 16, 25]
# d) None of the above
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
sqr = lambda x: x ** x
sqr(6)

# a) 6
# b) 36
# c) Error
# d) None of the above
# Out:
# 46656

# %%
n = '0101'
dec_n = int(n, base = 2)
print(dec_n)

# a) 0101
# b) 101
# c) 5
# d) None of the above
# Out:
# 5

# %%
words = ['This', 'is', 'a', 'list', 'of', 'keywords']
print(max(words, key=len))

# a) This
# b) keywords
# c) Error
# d) None of the above
# Out:
# keywords

# %%
print('even') if 5%2==0 else print('odd')

# a) even
# b) odd
# c) Error
# d) None of the above
# Out:
# odd

# %%
my_dict = {1:'one', 2:'two', 3:'three'}
for key, value in my_dict:
    print(key, my_dict[key])
    
# a) 1 one, 2 two, 3 three
# b) (1, 'one'), (2, 'two'), (3, 'three')
# c) {1: 'one', 2: 'two', 3: 'three'}
# d) None of the above
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Личные документы\Python\Py\useful_things\quiz.ipynb Cell 24 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/useful_things/quiz.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> my_dict = {1:'one', 2:'two', 3:'three'}
# ----> <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/useful_things/quiz.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> for key, value in my_dict:
#       <a href='vscode-notebook-cell:/c%3A/%D0%9B%D0%B8%D1%87%D0%BD%D1%8B%D0%B5%20%D0%B4%D0%BE%D0%BA%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B/Python/Py/useful_things/quiz.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>     print(key, my_dict[key])
#
# TypeError: cannot unpack non-iterable int object

# %%
def func(x):
    return x * 2

result = func(2)
result = func(result)
result = func(result)
print(result)

# a) 2
# b) 4
# c) 16
# d) None of the above
# Out:
# 16

# %%
t_1 = ('this', 'is', 'some', 'keys')
t_2 = ('this', 'is', 'some', 'object', 'with', 'values')
print(dict(zip(t_1, t_2))['keys'])

# a) values
# b) object
# c) 3
# d) None of the above
# Out:
# object

# %%
x = 5
y = x > 3
print(y)

# a) False
# b) 5
# c) 3
# d) None of the above
# Out:
# True

# %%
lst = ['W']
lst.extend('hat!')
print(lst)

# a) ['W', 'h', 'a', 't', '!']
# b) ['W', 'hat!']
# c) ['What!]
# d) None of the above
# Out:
# ['W', 'h', 'a', 't', '!']

# %%
lst = [1, 2, 3, 4, 5]
print(lst[slice(2,4)])

# a) [1, 2, 3, 4, 5]
# b) [3]
# c) [3, 4]
# d) None of the above
# Out:
# [3, 4]

# %%
lst = ['aa', 'bb', 'cc', 'ab', 'bc', 'ca']
print(lst[2:][:2])

# a) ['cc', 'cc']
# b) ['cc', 'bc']
# c) ['cc', 'ab']
# d) None of the above
# Out:
# ['cc', 'ab']

# %%
x = [1, 2, 3, 4, 5]
y = x
y[2] = 10
print(x)

# a) [1, 2, 3, 4, 5]
# b) [1, 2, 10, 4, 5]
# c) Error
# d) None of the above
# Out:
# [1, 2, 10, 4, 5]

# %%
a, *b = 10, 20, 30
print(type(b))

# a) <class 'list'>
# b) <class 'int'>
# c) <class 'tuple'>
# d) None of the above
# Out:
# <class 'list'>

# %%
num = [1, '1', -1, [], (1)]
print(any(num), all(num))

# a) True False
# b) True True
# c) False False
# d) False True
# Out:
# True False

# %% [markdown]
# ***
#
# <img src=joy.png>

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(7, 8))
fig.patch.set_facecolor('black')
ax.patch.set_facecolor('black')

for i in np.arange(100):
    line = ax.plot(np.concatenate([
        np.random.uniform(i, i+0.5, 20),
        np.random.uniform(i+0.5, i+5, 5),
        np.random.uniform(i+0.6, i+5, 7),
        np.random.uniform(i+0.5, i+4, 5),
        np.random.uniform(i, i+0.6, 17)]), 'w')
ax.fill_between()
fig.set_figheight(7)
ax.text(0.2, 110, 'JOY DIVISION',fontname="Arial", fontsize = 54, c='w')
ax.text(0.2, 125, ' ',fontname="Arial", fontsize = 40, c='k')
ax.text(58, -25, ' ', fontname="Arial", fontsize = 34, c='k')
ax.text(-0.2, -12, 'UNKNOWN PLEASURES', fontname="Arial", fontsize = 31, c='w');

# %% [markdown]
# ``` python
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# fig, ax = plt.subplots(figsize=(7, 8))
# fig.patch.set_facecolor('black')
# ax.patch.set_facecolor('black')
#
# for i in np.arange(70):
#     line = ax.plot(np.concatenate([
#         np.random.uniform(i, i+0.5, 20),
#         np.random.uniform(i+0.5, i+3, 5),
#         np.random.uniform(i+0.6, i+4, 7),
#         np.random.uniform(i+0.5, i+3, 5),
#         np.random.uniform(i, i+0.6, 17)]), 'w')
#
# fig.set_figheight(7)
# ax.text(0.2, 75, 'JOY DIVISION',fontname="Arial", fontsize = 54, c='w')
# ax.text(0.2, 90, ' ',fontname="Arial", fontsize = 40, c='k')
# ax.text(58, -15, ' ', fontname="Arial", fontsize = 34, c='k')
# ax.text(-0.4, -8, 'UNKNOWN PLEASURES', fontname="Arial", fontsize = 31, c='w');
#
# ```
# ``` python
#
# matplotlib.pyplot.fill_between()
#
# ```
